# %%
#from sklift.datasets import fetch_hillstrom
import pandas as pd
import numpy as np 
from scipy import stats
from econml.dml import CausalForestDML
from sklearn.linear_model import LassoCV
from sklearn.metrics import classification_report
from causalml.metrics import plot_gain,auuc_score
from scipy.stats import spearmanr
from sklearn.model_selection import (
    RandomizedSearchCV,GridSearchCV,cross_val_score,train_test_split,GroupKFold,
    StratifiedShuffleSplit,cross_validate)
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn import tree

from sklift.metrics import uplift_at_k
from sklift.viz import plot_uplift_preds
from sklift.models import SoloModel,ClassTransformation,TwoModels
from sklift.metrics import uplift_by_percentile
from sklift.viz import plot_uplift_by_percentile
from sklift.viz import plot_qini_curve,plot_uplift_curve
from sklift.metrics import qini_auc_score,uplift_auc_score

from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.dataset import *
from causalml.metrics import *

import scipy
import seaborn as sns
import time
import warnings
from matplotlib import pyplot as plt
from joblib import dump, load
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# 背景：
# 这是 MineThatData 电子邮件分析和数据挖掘挑战数据集的副本。
# 该数据集包含 64,000 名在十二个月内最后一次购买的客户。 客户参与了电子邮件测试。
# 1/3 被随机选择接收以男士商品为特色的电子邮件活动。
# 1/3 被随机选择接收以女士商品为特色的电子邮件活动。
# 1/3 被随机选择不接收电子邮件活动。
# 在电子邮件活动之后的两周内，对结果进行了跟踪。 你的工作是告诉全世界男士或女士电子邮件活动是否成功。
#
# 数据集由 Kevin Hillstorm 提供。 Kevin 是 MineThatData 的总裁，该公司是一家帮助 CEO 了解客户、广告、产品、品牌和渠道之间复杂关系的咨询公司。

# %%
data = pd.read_csv('../hillstrom_data/womens_exp_data.csv', sep='\t')
data.sample()
# Out:
#       recency  history_segment  history  mens  womens  zip_code  newbie  \
# 2200        2              425   376.46     1       1         2       0
#
#       channel_phone  channel_web  segment_mens  segment_womens  visit  \
# 2200              1            0             0               1      0
#
#       conversion  spend  history_norm
# 2200           0    0.0      6.033476

# %%
len(data)
# Out:
# 42693

# %%
## 描述性分析
data.describe()
# Out:
#             recency  history_segment       history          mens  \
# count  42693.000000     42693.000000  42693.000000  42693.000000
# mean       5.758789       240.377814    241.711212      0.551074
# std        3.504745       229.779937    254.040262      0.497390
# min        1.000000        50.000000     29.990000      0.000000
# 25%        2.000000        50.000000     65.160000      0.000000
# 50%        5.000000       150.000000    158.460000      1.000000
# 75%        9.000000       275.000000    326.050000      1.000000
# max       12.000000      1000.000000   3345.930000      1.000000
#
#              womens      zip_code        newbie  channel_phone   channel_web  \
# count  42693.000000  42693.000000  42693.000000   42693.000000  42693.000000
# mean       0.548872      2.252454      0.502612       0.561357      0.560092
# std        0.497612      0.696275      0.499999       0.496227      0.496382
# min        0.000000      1.000000      0.000000       0.000000      0.000000
# 25%        0.000000      2.000000      0.000000       0.000000      0.000000
# 50%        1.000000      2.000000      1.000000       1.000000      1.000000
# 75%        1.000000      3.000000      1.000000       1.000000      1.000000
# max        1.000000      3.000000      1.000000       1.000000      1.000000
#
#        segment_mens  segment_womens         visit    conversion         spend  \
# count       42693.0    42693.000000  42693.000000  42693.000000  42693.000000
# mean            0.0        0.500949      0.128827      0.007285      0.865398
# std             0.0        0.500005      0.335012      0.085039     13.472998
# min             0.0        0.000000      0.000000      0.000000      0.000000
# 25%             0.0        0.000000      0.000000      0.000000      0.000000
# 50%             0.0        1.000000      0.000000      0.000000      0.000000
# 75%             0.0        1.000000      0.000000      0.000000      0.000000
# max             0.0        1.000000      1.000000      1.000000    499.000000
#
#        history_norm
# count  42693.000000
# mean       5.073125
# std        1.056974
# min        3.434457
# 25%        4.227593
# 50%        5.140269
# 75%        5.884771
# max        8.308546

# %%
data
# Out:
#        recency  history_segment  history  mens  womens  zip_code  newbie  \
# 0           10              150   142.44     1       0         2       0
# 1            7              150   180.65     0       1         2       1
# 2            2               50    45.34     1       0         3       0
# 3            6              150   134.83     0       1         2       0
# 4            9              275   280.20     1       0         2       1
# ...        ...              ...      ...   ...     ...       ...     ...
# 42688        3              425   487.10     0       1         2       1
# 42689        4              150   125.53     0       1         1       1
# 42690        2               50    83.03     0       1         3       0
# 42691        1               50    79.70     1       0         2       1
# 42692        6               50    80.02     0       1         2       0
#
#        channel_phone  channel_web  segment_mens  segment_womens  visit  \
# 0                  1            0             0               1      0
# 1                  0            1             0               1      0
# 2                  0            1             0               1      0
# 3                  1            0             0               1      1
# 4                  1            0             0               1      0
# ...              ...          ...           ...             ...    ...
# 42688              1            0             0               0      0
# 42689              1            0             0               0      0
# 42690              1            0             0               0      0
# 42691              0            1             0               0      0
# 42692              1            0             0               0      0
#
#        conversion  spend  history_norm
# 0               0    0.0      5.030560
# 1               0    0.0      5.275267
# 2               0    0.0      3.856478
# 3               0    0.0      4.974069
# 4               0    0.0      5.728146
# ...           ...    ...           ...
# 42688           0    0.0      6.300304
# 42689           0    0.0      4.900562
# 42690           0    0.0      4.476036
# 42691           0    0.0      4.434052
# 42692           0    0.0      4.438161
#
# [42693 rows x 15 columns]

# %%
treatment = 'segment_womens'
## 划分训练集、验证集、测试集
X_train_exp, X_test_exp = train_test_split(data[data['segment_womens']==1], test_size=0.3, random_state=1)
X_train_exp, X_verify_exp = train_test_split(X_train_exp, test_size=0.3, random_state=1)

X_train_base, X_test_base = train_test_split(data[data['segment_womens']==0], test_size=0.3, random_state=1)
X_train_base, X_verify_base = train_test_split(X_train_base, test_size=0.3, random_state=1)

X_train = X_train_exp.append(X_train_base)
X_verify = X_verify_exp.append(X_verify_base)
X_test = X_test_exp.append(X_test_base)

# %%
print(len(X_train))
print(len(X_verify))
print(len(X_test))
# Out:
# 20918
# 8966
# 12809

# %%
X_columns = ['recency', 'history_segment', 'history', 'mens', 'womens', 'zip_code',
       'newbie', 'channel_phone', 'channel_web']
y_columns = 'visit'

# %%
# cia
f1_micro = cross_val_score(
    X=data[X_columns],
    y=data[treatment],
    estimator= LGBMClassifier(random_state=42, n_jobs=-1),
    scoring='f1_micro', 
    cv=3)
print(f'F1 micro {f1_micro.mean():.2f}')
# Out:
# F1 micro 0.50

# %% [markdown]
# 建模（尝试多种模型）和模型评价

# %%
def get_cuts_mean(df, cuts):
    cuts_mean = []
    for i in range(0, len(cuts)):
        if i == 0:
            mean_value = df[df['uplift'] > cuts[i]]['uplift'].mean()
        else:
            mean_value = df[(df['uplift'] <= cuts[i-1]) & (df['uplift'] > cuts[i])]['uplift'].mean()
        cuts_mean.append(mean_value)
    mean_value = df[df['uplift'] <= cuts[-1]]['uplift'].mean()
    cuts_mean.append(mean_value)
    return cuts_mean

def get_uplift_cut(x, cuts):
    percent = scipy.stats.percentileofscore(cuts, x)/100
    index = int(percent*(len(cuts)+1)) if int(percent*(len(cuts)+1)) <= len(cuts) else len(cuts)
    return len(cuts)-index

def plot_uplift(df, bins=10, treatment='treatment', metric='label', is_plot=True):
    cuts = [np.percentile(df['uplift'], i) for i in range(100-int(100/bins),0 , -int(100/bins))]
    cuts_mean = get_cuts_mean(df,cuts)
    df['pre_uplift_score'] = df['uplift'].apply(lambda x: cuts_mean[get_uplift_cut(x, cuts)])
    df2 = df.groupby([treatment, 'pre_uplift_score'])[metric].mean().reset_index()
    act_df = pd.DataFrame()
    act_df['uplift_score'] = df2[df2[treatment]==1].reset_index()[metric] - df2[df2[treatment]==0].reset_index()[metric]
    act_df['type'] = 'actual'
    pre_df = pd.DataFrame()
    pre_df['uplift_score'] = df2[df2[treatment]==0]['pre_uplift_score']
    pre_df['type'] = 'predict'
    new_df = act_df.append(pre_df)
    if is_plot:
        print(new_df)
        sns.set(rc={'figure.figsize':(11.7,8.27)})
        #sns.barplot(x=new_df.index, y='uplift_score', hue='type', data=new_df, order=[i for i in range(bins-1,-1,-1)])
        sns.barplot(x=new_df.index, y='uplift_score', hue='type', data=new_df, order=[i for i in range(bins-1,-1,-1)])
    return new_df

# %% [markdown]
# #### Part1: two model & one model
# * two model是每个treatment各建立一个模型，模型之间计算delta作为预测的CATE
# * one model是将treatment作为一个特征，跟其他特征一起训练，同一个模型不同的Treatment值代入后计算delta作为预测的CATE

# %%
def pareto_result(auc_score, monotonicity, old_result, params=None):
    is_add = False
    length = len(old_result)
    new_result = old_result.copy()
    for i in range(length):
        if auc_score > old_result[i]['auc_score'] and monotonicity > old_result[i]['monotonicity']:
            new_result.remove(old_result[i])
        
        if auc_score <= old_result[i]['auc_score'] and monotonicity <= old_result[i]['monotonicity']:
            return new_result
    
    new_result.append({'auc_score': auc_score, 'monotonicity': monotonicity, 'params':params})
    return new_result

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.01, 0.02,0.03], 'n_estimators':[30,40,50,60], 
#                 'criterion':['friedman_mse'],
#                'min_samples_leaf': [1], 'max_depth': [2,3,4]}

search_params = {'learning_rate': [0.02], 'n_estimators':[60], 
                'criterion':['friedman_mse'],
                'min_samples_leaf': [1], 'max_depth': [2]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for criterion in search_params['criterion']:
            print('criterion: %s' % criterion)
            for min_samples_leaf in search_params['min_samples_leaf']:
                print('min_samples_leaf: %s' % min_samples_leaf)
                for max_depth in search_params['max_depth']:
                    print('max_depth: %s' % max_depth)

                    model1 = GradientBoostingRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      criterion=criterion, min_samples_leaf=min_samples_leaf,
                                                      max_depth=max_depth) 
                    model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                    y_train_pred1 = model1.predict(X_train[X_columns])
                    y_verify_pred1 = model1.predict(X_verify[X_columns])

                    model2 = GradientBoostingRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      criterion=criterion, min_samples_leaf=min_samples_leaf,
                                                      max_depth=max_depth) 
                    model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                    y_train_pred2 = model2.predict(X_train[X_columns])
                    y_verify_pred2= model2.predict(X_verify[X_columns])

                    X_train['uplift'] = y_train_pred1 - y_train_pred2
                    X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                    train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                    verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                    new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                    monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                    new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                    monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                    print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                    print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                    best_result = pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                                 {'learning_rate': learning_rate,'criterion':criterion,'n_estimators': n_estimators, \
                              'min_samples_leaf':min_samples_leaf, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.02
# n_estimators: 60
# criterion: friedman_mse
# min_samples_leaf: 1
# max_depth: 2
# train_qini_auc_score: 0.08577528219728955, verify_qini_auc_score: 0.07336102002395975
# monotonicity_train: 0.9393939393939393, monotonicity_verify: 0.709090909090909
# [{'auc_score': 0.07336102002395975, 'monotonicity': 0.709090909090909, 'params': {'learning_rate': 0.02, 'criterion': 'friedman_mse', 'n_estimators': 60, 'min_samples_leaf': 1, 'max_depth': 2}}]

# %%
# 模型保存
dump(model1, 'result/womens_visit/gbdt_model1_rm_norm.joblib')
dump(model2, 'result/womens_visit/gbdt_model2_rm_norm.joblib')
# Out:
# ['result/womens_visit/gbdt_model2_rm_norm.joblib']

# %%
'''
best_param:
learning_rate: 0.02
n_estimators: 50
criterion: friedman_mse
min_samples_leaf: 1
max_depth: 2
    
best_auuc_param:
n_estimators: 60
criterion: friedman_mse
min_samples_leaf: 1
max_depth: 2
'''
# Out:
# '\nbest_param:\nlearning_rate: 0.02\nn_estimators: 50\ncriterion: friedman_mse\nmin_samples_leaf: 1\nmax_depth: 2\n    \nbest_auuc_param:\nn_estimators: 60\ncriterion: friedman_mse\nmin_samples_leaf: 1\nmax_depth: 2\n'

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.08577528219728955
# 0.07336102002395975

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0370'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.001,0.005,0.01], 'n_estimators':[20,30,40], 
#                'subsample':[0.35,0.4,0.45], 'max_depth': [2]}

search_params = {'learning_rate': [0.01], 'n_estimators':[40], 
                'subsample':[0.4], 'max_depth': [2]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for subsample in search_params['subsample']:
            print('subsample: %s' % subsample)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model1 = XGBRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                y_train_pred1 = model1.predict(X_train[X_columns])
                y_verify_pred1 = model1.predict(X_verify[X_columns])
                
                model2 = XGBRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                y_train_pred2 = model2.predict(X_train[X_columns])
                y_verify_pred2= model2.predict(X_verify[X_columns])

                X_train['uplift'] = y_train_pred1 - y_train_pred2
                X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result,\
                             {'learning_rate': learning_rate,'n_estimators': n_estimators, \
                              'subsample':subsample, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.01
# n_estimators: 40
# subsample: 0.4
# max_depth: 2
# train_qini_auc_score: 0.08523970673777519, verify_qini_auc_score: 0.08064815769141946
# monotonicity_train: 0.8666666666666665, monotonicity_verify: 0.8545454545454544
# [{'auc_score': 0, 'monotonicity': 0}]

# %%
'''
best_params:
learning_rate: 0.01
n_estimators: 40
subsample: 0.4
max_depth: 2
'''
# Out:
# '\nbest_params:\nlearning_rate: 0.01\nn_estimators: 40\nsubsample: 0.4\nmax_depth: 2\n'

# %%
# 模型保存
dump(model1, 'result/womens_visit/xgb_model1_rm_norm.joblib')
dump(model2, 'result/womens_visit/xgb_model2_rm_norm.joblib')
# Out:
# ['result/womens_visit/xgb_model2_rm_norm.joblib']

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.08523970673777519
# 0.08064815769141946

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0370'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.01,0.02,0.03], 'n_estimators':[40,50,60], 
#                'subsample':[0.3,0.4,0.5], 'max_depth': [2]}

search_params = {'learning_rate': [0.02], 'n_estimators':[50], 
                'subsample':[0.4], 'max_depth': [2]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for subsample in search_params['subsample']:
            print('subsample: %s' % subsample)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model1 = CatBoostRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                y_train_pred1 = model1.predict(X_train[X_columns])
                y_verify_pred1 = model1.predict(X_verify[X_columns])
                
                model2 = CatBoostRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                y_train_pred2 = model2.predict(X_train[X_columns])
                y_verify_pred2= model2.predict(X_verify[X_columns])

                X_train['uplift'] = y_train_pred1 - y_train_pred2
                X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                              {'learning_rate':learning_rate,'n_estimators': n_estimators, \
                              'subsample':subsample, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.02
# n_estimators: 50
# subsample: 0.4
# max_depth: 2
# 0:	learn: 0.3586842	total: 65.2ms	remaining: 3.19s
# 1:	learn: 0.3585801	total: 66.5ms	remaining: 1.59s
# 2:	learn: 0.3584958	total: 67.4ms	remaining: 1.06s
# 3:	learn: 0.3583984	total: 68.3ms	remaining: 786ms
# 4:	learn: 0.3583175	total: 69.6ms	remaining: 626ms
# 5:	learn: 0.3582559	total: 70.9ms	remaining: 520ms
# 6:	learn: 0.3581711	total: 71.6ms	remaining: 440ms
# 7:	learn: 0.3580957	total: 72.4ms	remaining: 380ms
# 44:	learn: 0.3060264	total: 29.5ms	remaining: 3.28ms
# 45:	learn: 0.3059961	total: 30.1ms	remaining: 2.62ms
# 46:	learn: 0.3059658	total: 30.8ms	remaining: 1.96ms
# 47:	learn: 0.3059428	total: 31.4ms	remaining: 1.31ms
# 48:	learn: 0.3059115	total: 32.1ms	remaining: 654us
# 49:	learn: 0.3058871	total: 32.7ms	remaining: 0us
# train_qini_auc_score: 0.08133202078916406, verify_qini_auc_score: 0.08245672040678748
# monotonicity_train: 0.8787878787878788, monotonicity_verify: 0.6848484848484848
# [{'auc_score': 0, 'monotonicity': 0}]

# %%
# 模型保存
dump(model1, 'result/womens_visit/cat_boost_model1_rm_norm.joblib')
dump(model2, 'result/womens_visit/cat_boost_model2_rm_norm.joblib')
# Out:
# ['result/womens_visit/cat_boost_model2_rm_norm.joblib']

# %%
# best_params
#{'learning_rate': 0.02, 'n_estimators': 50, 'subsample': 0.4, 'max_depth': 2}

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.08133202078916406
# 0.08245672040678748

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0370'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %% [markdown]
# #### Part3 因果森林

# %%
### 因果森林 econml.dml.CausalForestDML

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'n_estimators':[40,60,80,100,200], 
#                'min_samples_leaf': [1], 'max_depth': [2,3,5],
#                'max_samples': [0.3,0.4,0,5]}

search_params = {
    'n_estimators': [20],
    'min_samples_leaf': [1],
    'max_depth': [2],
    'max_samples': [0.5]
}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for max_samples in search_params['max_samples']:
    print('max_samples: %s' % max_samples)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for min_samples_leaf in search_params['min_samples_leaf']:
            print('min_samples_leaf: %s' % min_samples_leaf)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model = CausalForestDML(criterion='het', 
                                max_depth=max_depth,
                                n_estimators=n_estimators,  
                                min_samples_leaf=min_samples_leaf, 
                                max_samples=max_samples,
                                discrete_treatment=True,
                                honest=True,
                                inference=True,
                                cv=5)
                model.fit(X_train[y_columns], X_train[[treatment]], X=X_train[X_columns], W=None, cache_values=True)
                X_train['uplift'] = model.effect(X_train[X_columns])
                X_verify['uplift'] = model.effect(X_verify[X_columns])
                    
                train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                             {'max_samples':max_samples,'n_estimators': n_estimators, \
                              'min_samples_leaf':min_samples_leaf, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# max_samples: 0.5
# n_estimators: 20
# min_samples_leaf: 1
# max_depth: 2
# train_qini_auc_score: 0.06804454796406927, verify_qini_auc_score: 0.05649025369631539
# monotonicity_train: 0.8303030303030302, monotonicity_verify: 0.6606060606060605
# [{'auc_score': 0, 'monotonicity': 0}]

# %%
# 模型保存
dump(model, 'result/womens_visit/causal_forest_model_rm_norm.joblib')
# Out:
# ['result/womens_visit/causal_forest_model_rm_norm.joblib']

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.06804454796406927
# 0.05649025369631539

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0370'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
# 连续变量
#plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)
#auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)

# %%
## 多模型比较
gbdt_model1 = load('result/womens_visit/gbdt_model1_rm_norm.joblib')
gbdt_model2 = load('result/womens_visit/gbdt_model2_rm_norm.joblib')

X_test['gbdt_uplift'] = gbdt_model1.predict(X_test[X_columns]) - gbdt_model2.predict(X_test[X_columns])

xgb_model1 = load('result/womens_visit/xgb_model1_rm_norm.joblib')
xgb_model2 = load('result/womens_visit/xgb_model2_rm_norm.joblib')

X_test['xgb_uplift'] = xgb_model1.predict(X_test[X_columns]) - xgb_model2.predict(X_test[X_columns])

cat_boost_model1 = load('result/womens_visit/cat_boost_model1_rm_norm.joblib')
cat_boost_model2 = load('result/womens_visit/cat_boost_model2_rm_norm.joblib')

X_test['cat_boost_uplift'] = cat_boost_model1.predict(X_test[X_columns]) - cat_boost_model2.predict(X_test[X_columns])

causal_forest_model = load('result/womens_visit/causal_forest_model_rm_norm.joblib')
X_test['causal_forest_uplift'] = causal_forest_model.effect(X_test[X_columns])
#X_test['causal_forest_uplift'] = causal_forest_model.const_marginal_effect(X_test[X_columns])

# %%
fig, ax = plt.subplots(1, 1)
ax.set_title('Qini curves')
plot_qini_curve(X_test[y_columns], X_test['gbdt_uplift'], X_test[treatment], perfect=False, name='GBDT', ax=ax)
plot_qini_curve(X_test[y_columns], X_test['xgb_uplift'], X_test[treatment], perfect=False, name='XGB', ax=ax)
plot_qini_curve(X_test[y_columns], X_test['cat_boost_uplift'], X_test[treatment], perfect=False, name='CAT_BOOST', ax=ax)
plot_qini_curve(X_test[y_columns], X_test['causal_forest_uplift'], X_test[treatment], perfect=False, name='CAUSAL_FOREST', ax=ax)
print('GBDT QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['gbdt_uplift'], X_test[treatment]))
print('XGB QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['xgb_uplift'], X_test[treatment]))
print('CAT BOOST QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['cat_boost_uplift'], X_test[treatment]))
print('CAUSAL FOREST SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['causal_forest_uplift'], X_test[treatment]))


X_test['uplift'] = X_test['gbdt_uplift']
new_df = plot_uplift(X_test, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
monotonicity = spearmanr(new_df[new_df['type']=='actual'].index,new_df[new_df['type']=='actual']['uplift_score'])[0]
print('GBDT monotonicity: %s' % monotonicity)
X_test['uplift'] = X_test['xgb_uplift']
new_df = plot_uplift(X_test, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
monotonicity = spearmanr(new_df[new_df['type']=='actual'].index,new_df[new_df['type']=='actual']['uplift_score'])[0]
print('XGB monotonicity: %s' % monotonicity)
X_test['uplift'] = X_test['cat_boost_uplift']
new_df = plot_uplift(X_test, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
monotonicity = spearmanr(new_df[new_df['type']=='actual'].index,new_df[new_df['type']=='actual']['uplift_score'])[0]
print('CAT BOOST monotonicity: %s' % monotonicity)
X_test['uplift'] = X_test['causal_forest_uplift']
new_df = plot_uplift(X_test, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
monotonicity = spearmanr(new_df[new_df['type']=='actual'].index,new_df[new_df['type']=='actual']['uplift_score'])[0]
print('CAUSAL FOREST monotonicity: %s' % monotonicity)
# Out:
# GBDT QINI SCORE: 0.0693118252146051
# XGB QINI SCORE: 0.06686921428371723
# CAT BOOST QINI SCORE: 0.0693118252146051
# CAUSAL FOREST SCORE: 0.07069716256774504
# GBDT monotonicity: 0.7454545454545454
# XGB monotonicity: 0.8060606060606059
# CAT BOOST monotonicity: 0.7454545454545454
# CAUSAL FOREST monotonicity: 0.8545454545454544

# %% [markdown]
# ## 第四部分：收益回归
# uplift排名前15%的人群收益和uplift排名后15%的人群收益（也用来衡量偏序关系寻优的效果）

# %%
bottom = np.percentile(X_test['causal_forest_uplift'], 15)
up = np.percentile(X_test['causal_forest_uplift'], 100-15)

# %%
up
# Out:
# 0.07587758724206901

# %%
good = X_test[X_test['causal_forest_uplift']>=up]
bad = X_test[X_test['causal_forest_uplift']<=bottom]
print(len(good))
print(len(bad))
print(len(X_test))
# Out:
# 2225
# 2008
# 12809

# %%
def get_detail(exp_mean, base_mean):
    abs_diff = exp_mean - base_mean
    rel_diff = abs_diff/base_mean
    return exp_mean, base_mean, abs_diff, rel_diff

# %%
good_exp = good[good[treatment]==1]
good_base = good[good[treatment]==0]
print('good人群对visit的处理效应：%s,%s,%s,%s' % get_detail(good_exp['visit'].mean(),good_base['visit'].mean()))
print('good人群对conversion的处理效应：%s,%s,%s,%s' % get_detail(good_exp['conversion'].mean(),good_base['conversion'].mean()))
print('good人群对spend的处理效应：%s,%s,%s,%s' % get_detail(good_exp['spend'].mean(),good_base['spend'].mean()))
# Out:
# good人群对visit的处理效应：0.16247755834829444,0.0774077407740774,0.08506981757421704,1.0989833409878504
# good人群对conversion的处理效应：0.01526032315978456,0.0054005400540054005,0.00985978310577916,1.825703171753441
# good人群对spend的处理效应：1.4253770197486535,0.7841224122412241,0.6412546075074294,0.817799105721973

# %%
bad_exp = bad[bad[treatment]==1]
bad_base = bad[bad[treatment]==0]
print('bad人群对visit的处理效应：%s,%s,%s,%s' % get_detail(bad_exp['visit'].mean(),bad_base['visit'].mean()))
print('bad人群对conversion的处理效应：%s,%s,%s,%s' % get_detail(bad_exp['conversion'].mean(),bad_base['conversion'].mean()))
print('bad人群对spend的处理效应：%s,%s,%s,%s' % get_detail(bad_exp['spend'].mean(),bad_base['spend'].mean()))
# Out:
# bad人群对visit的处理效应：0.1079429735234216,0.10818713450292397,-0.00024416097950237525,-0.002256839324048982
# bad人群对conversion的处理效应：0.003054989816700611,0.007797270955165692,-0.004742281138465081,-0.6081975560081466
# bad人群对spend的处理效应：0.560091649694501,0.9160916179337233,-0.3559999682392223,-0.3886073851894778

# %% [markdown]
# ## 第五部分：提炼人群共性

# %%
label = 'causal_forest_uplift'

search_params = {'criterion': ['mse'],
                'max_depth': [3],
                'max_features': ['auto'],
                'min_impurity_decrease': [0]}

tree_train, tree_test = train_test_split(X_test, test_size=0.3, random_state=0)
# Out:
# criterion: mse
# max_depth: 3
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 0.9931573898541148, tree_test_score: 0.9929252223746938
# 0.9929252223746938
# {'criterion': 'mse', 'max_depth': 3, 'max_features': 'auto', 'min_impurity_decrease': 0}

# %%
print(len(tree_train))
print(len(tree_test))
# Out:
# 8966
# 3843

# %%
## 调整min_impurity_decrease参数
tree_model = DecisionTreeRegressor(criterion='mse',
                                                 splitter='best',
                                                 max_depth=None,
                                                 min_samples_split=2,
                                                 min_samples_leaf=1,
                                                 min_weight_fraction_leaf=0,
                                                 max_features='auto',
                                                 random_state=1,
                                                 max_leaf_nodes=None,
                                                 min_impurity_decrease=0.0000004)
tree_model.fit(tree_train[X_columns], tree_train[label])
                
tree_train_score = tree_model.score(tree_train[X_columns], tree_train[label])
tree_test_score = tree_model.score(tree_test[X_columns], tree_test[label])

# %%
print(tree_train_score)
print(tree_test_score)
# Out:
# 0.9962445829872062
# 0.9962607295935005

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(tree_model, 
                   feature_names=X_columns,  
                   filled=True,
                   impurity=False,
                   precision=4)
