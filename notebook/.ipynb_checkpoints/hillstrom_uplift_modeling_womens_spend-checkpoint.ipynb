# %%
#from sklift.datasets import fetch_hillstrom
import pandas as pd
import numpy as np 
from scipy import stats
from econml.dml import CausalForestDML
from sklearn.linear_model import LassoCV
from sklearn.metrics import classification_report
from causalml.metrics import plot_gain,auuc_score
from scipy.stats import spearmanr
from sklearn.model_selection import (
    RandomizedSearchCV,GridSearchCV,cross_val_score,train_test_split,GroupKFold,
    StratifiedShuffleSplit,cross_validate)
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn import tree

from sklift.metrics import uplift_at_k
from sklift.viz import plot_uplift_preds
from sklift.models import SoloModel,ClassTransformation,TwoModels
from sklift.metrics import uplift_by_percentile
from sklift.viz import plot_uplift_by_percentile
from sklift.viz import plot_qini_curve,plot_uplift_curve
from sklift.metrics import qini_auc_score,uplift_auc_score

from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.dataset import *
from causalml.metrics import *

import scipy
import seaborn as sns
import time
import warnings
from matplotlib import pyplot as plt
from joblib import dump, load
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# 背景：
# 这是 MineThatData 电子邮件分析和数据挖掘挑战数据集的副本。
# 该数据集包含 64,000 名在十二个月内最后一次购买的客户。 客户参与了电子邮件测试。
# 1/3 被随机选择接收以男士商品为特色的电子邮件活动。
# 1/3 被随机选择接收以女性商品为特色的电子邮件活动。
# 1/3 被随机选择不接收电子邮件活动。
# 在电子邮件活动之后的两周内，对结果进行了跟踪。 你的工作是告诉全世界男士或女士电子邮件活动是否成功。
#
# 数据集由 Kevin Hillstorm 提供。 Kevin 是 MineThatData 的总裁，该公司是一家帮助 CEO 了解客户、广告、产品、品牌和渠道之间复杂关系的咨询公司。

# %%
data = pd.read_csv('../hillstrom_data/womens_exp_data.csv', sep='\t')
data.sample()
# Out:
#        recency  history_segment  history  mens  womens  zip_code  newbie  \
# 11664        1               50    80.76     0       1         2       0
#
#        channel_phone  channel_web  segment_mens  segment_womens  visit  \
# 11664              1            0             0               1      0
#
#        conversion  spend  history_norm
# 11664           0    0.0      4.447602

# %%
len(data)
# Out:
# 42693

# %%
data.describe()
# Out:
#             recency  history_segment       history          mens  \
# count  42693.000000     42693.000000  42693.000000  42693.000000
# mean       5.758789       240.377814    241.711212      0.551074
# std        3.504745       229.779937    254.040262      0.497390
# min        1.000000        50.000000     29.990000      0.000000
# 25%        2.000000        50.000000     65.160000      0.000000
# 50%        5.000000       150.000000    158.460000      1.000000
# 75%        9.000000       275.000000    326.050000      1.000000
# max       12.000000      1000.000000   3345.930000      1.000000
#
#              womens      zip_code        newbie  channel_phone   channel_web  \
# count  42693.000000  42693.000000  42693.000000   42693.000000  42693.000000
# mean       0.548872      2.252454      0.502612       0.561357      0.560092
# std        0.497612      0.696275      0.499999       0.496227      0.496382
# min        0.000000      1.000000      0.000000       0.000000      0.000000
# 25%        0.000000      2.000000      0.000000       0.000000      0.000000
# 50%        1.000000      2.000000      1.000000       1.000000      1.000000
# 75%        1.000000      3.000000      1.000000       1.000000      1.000000
# max        1.000000      3.000000      1.000000       1.000000      1.000000
#
#        segment_mens  segment_womens         visit    conversion         spend  \
# count       42693.0    42693.000000  42693.000000  42693.000000  42693.000000
# mean            0.0        0.500949      0.128827      0.007285      0.865398
# std             0.0        0.500005      0.335012      0.085039     13.472998
# min             0.0        0.000000      0.000000      0.000000      0.000000
# 25%             0.0        0.000000      0.000000      0.000000      0.000000
# 50%             0.0        1.000000      0.000000      0.000000      0.000000
# 75%             0.0        1.000000      0.000000      0.000000      0.000000
# max             0.0        1.000000      1.000000      1.000000    499.000000
#
#        history_norm
# count  42693.000000
# mean       5.073125
# std        1.056974
# min        3.434457
# 25%        4.227593
# 50%        5.140269
# 75%        5.884771
# max        8.308546

# %%
data
# Out:
#        recency  history_segment  history  mens  womens  zip_code  newbie  \
# 0           10              150   142.44     1       0         2       0
# 1            7              150   180.65     0       1         2       1
# 2            2               50    45.34     1       0         3       0
# 3            6              150   134.83     0       1         2       0
# 4            9              275   280.20     1       0         2       1
# ...        ...              ...      ...   ...     ...       ...     ...
# 42688        3              425   487.10     0       1         2       1
# 42689        4              150   125.53     0       1         1       1
# 42690        2               50    83.03     0       1         3       0
# 42691        1               50    79.70     1       0         2       1
# 42692        6               50    80.02     0       1         2       0
#
#        channel_phone  channel_web  segment_mens  segment_womens  visit  \
# 0                  1            0             0               1      0
# 1                  0            1             0               1      0
# 2                  0            1             0               1      0
# 3                  1            0             0               1      1
# 4                  1            0             0               1      0
# ...              ...          ...           ...             ...    ...
# 42688              1            0             0               0      0
# 42689              1            0             0               0      0
# 42690              1            0             0               0      0
# 42691              0            1             0               0      0
# 42692              1            0             0               0      0
#
#        conversion  spend  history_norm
# 0               0    0.0      5.030560
# 1               0    0.0      5.275267
# 2               0    0.0      3.856478
# 3               0    0.0      4.974069
# 4               0    0.0      5.728146
# ...           ...    ...           ...
# 42688           0    0.0      6.300304
# 42689           0    0.0      4.900562
# 42690           0    0.0      4.476036
# 42691           0    0.0      4.434052
# 42692           0    0.0      4.438161
#
# [42693 rows x 15 columns]

# %%
treatment = 'segment_womens'
## 划分训练集、验证集、测试集
X_train_exp, X_test_exp = train_test_split(data[data['segment_womens']==1], test_size=0.3, random_state=1)
X_train_exp, X_verify_exp = train_test_split(X_train_exp, test_size=0.3, random_state=1)

X_train_base, X_test_base = train_test_split(data[data['segment_womens']==0], test_size=0.3, random_state=1)
X_train_base, X_verify_base = train_test_split(X_train_base, test_size=0.3, random_state=1)

X_train = X_train_exp.append(X_train_base)
X_verify = X_verify_exp.append(X_verify_base)
X_test = X_test_exp.append(X_test_base)

# %%
X_columns = ['recency', 'history_segment', 'history_norm', 'history', 'mens', 'womens', 'zip_code',
       'newbie', 'channel_phone', 'channel_web']
y_columns = 'spend'

# %%
f1_micro = cross_val_score(
    X=data[X_columns],
    y=data[treatment],
    estimator= LGBMClassifier(random_state=42, n_jobs=-1),
    scoring='f1_micro', 
    cv=3)
print(f'F1 micro {f1_micro.mean():.2f}')
# Out:
# F1 micro 0.50

# %% [markdown]
# ## 第三部分：建模（尝试多种模型）和模型评价
# 可用模型：
# * two-model：（1）任意的机器学习分类/回归模型；（2）封装好的模型MetaLearner
# * one-model：（1）任意的机器学习分类/回归模型；（2）封装好的模型MetaLearner
# * 标签转换模型（适用于visit和conversion）：（1）标签转换后，任意的机器学习分类模型。（2）封装好的模型：pylift.TransformedOutcome
# * 因果森林：（1）简单因果森林 causalml；（2）econml
#
# 模型评价：
# * mse
# * auuc score及图形
# * 单调性分数
# * 柱形图

# %%
def get_cuts_mean(df, cuts):
    cuts_mean = []
    for i in range(0, len(cuts)):
        if i == 0:
            mean_value = df[df['uplift'] > cuts[i]]['uplift'].mean()
        else:
            mean_value = df[(df['uplift'] <= cuts[i-1]) & (df['uplift'] > cuts[i])]['uplift'].mean()
        cuts_mean.append(mean_value)
    mean_value = df[df['uplift'] <= cuts[-1]]['uplift'].mean()
    cuts_mean.append(mean_value)
    return cuts_mean

def get_uplift_cut(x, cuts):
    percent = scipy.stats.percentileofscore(cuts, x)/100
    index = int(percent*(len(cuts)+1)) if int(percent*(len(cuts)+1)) <= len(cuts) else len(cuts)
    return len(cuts)-index

def plot_uplift(df, bins=10, treatment='treatment', metric='label', is_plot=True):
    cuts = [np.percentile(df['uplift'], i) for i in range(100-int(100/bins),0 , -int(100/bins))]
    cuts_mean = get_cuts_mean(df,cuts)
    df['pre_uplift_score'] = df['uplift'].apply(lambda x: cuts_mean[get_uplift_cut(x, cuts)])
    df2 = df.groupby([treatment, 'pre_uplift_score'])[metric].mean().reset_index()
    act_df = pd.DataFrame()
    act_df['uplift_score'] = df2[df2[treatment]==1].reset_index()[metric] - df2[df2[treatment]==0].reset_index()[metric]
    act_df['type'] = 'actual'
    pre_df = pd.DataFrame()
    pre_df['uplift_score'] = df2[df2[treatment]==0]['pre_uplift_score']
    pre_df['type'] = 'predict'
    new_df = act_df.append(pre_df)
    if is_plot:
        print(new_df)
        sns.set(rc={'figure.figsize':(11.7,8.27)})
        #sns.barplot(x=new_df.index, y='uplift_score', hue='type', data=new_df, order=[i for i in range(bins-1,-1,-1)])
        sns.barplot(x=new_df.index, y='uplift_score', hue='type', data=new_df, order=[i for i in range(bins-1,-1,-1)])
    return new_df

# %% [markdown]
# #### Part1: two model & one model
# * two model是每个treatment各建立一个模型，模型之间计算delta作为预测的CATE
# * one model是将treatment作为一个特征，跟其他特征一起训练，同一个模型不同的Treatment值代入后计算delta作为预测的CATE

# %%
def pareto_result(auc_score, monotonicity, old_result, params=None):
    for i in range(len(old_result)):
        if auc_score > old_result[i]['auc_score'] and monotonicity > old_result[i]['monotonicity']:
            old_result[i]['auc_score'] = auc_score
            old_result[i]['monotonicity'] = monotonicity
            old_result[i]['params'] = params
            return
        
        if auc_score <= old_result[i]['auc_score'] and monotonicity <= old_result[i]['monotonicity']:
            return 
        
    #old_result.append({'auc_score': auc_score, 'monotonicity': monotonicity, 'params':params})
    return

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.005, 0.01, 0.02], 'n_estimators':[10,15,20,25,30], 
#                 'criterion':['friedman_mse'],
#                'min_samples_leaf': [1], 'max_depth': [2,3,5,10,20,None]}

search_params = {'learning_rate': [0.01], 'n_estimators':[20], 
                'criterion':['friedman_mse'],
                'min_samples_leaf': [1], 'max_depth': [None]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for criterion in search_params['criterion']:
            print('criterion: %s' % criterion)
            for min_samples_leaf in search_params['min_samples_leaf']:
                print('min_samples_leaf: %s' % min_samples_leaf)
                for max_depth in search_params['max_depth']:
                    print('max_depth: %s' % max_depth)

                    model1 = GradientBoostingRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      criterion=criterion, min_samples_leaf=min_samples_leaf,
                                                      max_depth=max_depth) 
                    model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                    y_train_pred1 = model1.predict(X_train[X_columns])
                    y_verify_pred1 = model1.predict(X_verify[X_columns])

                    model2 = GradientBoostingRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      criterion=criterion, min_samples_leaf=min_samples_leaf,
                                                      max_depth=max_depth) 
                    model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                    y_train_pred2 = model2.predict(X_train[X_columns])
                    y_verify_pred2= model2.predict(X_verify[X_columns])

                    X_train['uplift'] = y_train_pred1 - y_train_pred2
                    X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                    #train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                    #verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                    # 连续y计算auuc score
                    train_qini_auc_score = auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                    verify_qini_auc_score = auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                    
                    new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                    monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                    new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                    monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                    print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                    print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                    pareto_result(verify_qini_auc_score, monotonicity_verify, best_result,\
                                 {'learning_rate': learning_rate,'criterion':criterion,'n_estimators': n_estimators, \
                              'min_samples_leaf':min_samples_leaf, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.01
# n_estimators: 20
# criterion: friedman_mse
# min_samples_leaf: 1
# max_depth: None
# train_qini_auc_score: 2.3338429940681564, verify_qini_auc_score: 0.8616794265990778
# monotonicity_train: 0.7637626158259734, monotonicity_verify: 0.6785714285714287
# [{'auc_score': 0.8616794265990778, 'monotonicity': 0.6785714285714287, 'params': {'learning_rate': 0.01, 'criterion': 'friedman_mse', 'n_estimators': 20, 'min_samples_leaf': 1, 'max_depth': None}}]

# %%
# 模型保存
dump(model1, 'result/womens_spend/gbdt_model1.joblib')
dump(model2, 'result/womens_spend/gbdt_model2.joblib')
# Out:
# ['result/womens_spend/gbdt_model2.joblib']

# %%
'''
best_param:
learning_rate: 0.02
n_estimators: 50
criterion: friedman_mse
min_samples_leaf: 1
max_depth: 2
    
best_auuc_param:
n_estimators: 60
criterion: friedman_mse
min_samples_leaf: 1
max_depth: 2
'''
# Out:
# '\nbest_param:\nlearning_rate: 0.02\nn_estimators: 50\ncriterion: friedman_mse\nmin_samples_leaf: 1\nmax_depth: 2\n    \nbest_auuc_param:\nn_estimators: 60\ncriterion: friedman_mse\nmin_samples_leaf: 1\nmax_depth: 2\n'

# %%
#plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
#plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
#print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment,n=len(X_train))
plot_gain(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment,n=len(X_verify))
print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
print(auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
# Out:
# 2.3338429940681564
# 0.8616794265990778

# %%
#plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
#                          strategy='by_group', kind='bar')
new_df_train = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10)
# Out:
#    uplift_score     type
# 0      0.008895   actual
# 1      0.187832   actual
# 2     -0.097478   actual
# 3     -0.558942   actual
# 4      0.529228   actual
# 5      0.774737   actual
# 6      2.137692   actual
# 0     -0.638293  predict
# 1      0.405725  predict
# 2      0.405725  predict
# 3      0.405725  predict
# 4      0.405725  predict
# 5      0.405725  predict
# 6      2.671675  predict

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.003,0.004,0.005,0.006,0.007], 'n_estimators':[30,40,50], 
#                'subsample':[0.2,0.25,0.3,0.35,0.4], 'max_depth': [5,10,20,None]}

search_params = {'learning_rate': [0.005], 'n_estimators':[30], 
                'subsample':[0.52], 'max_depth': [20]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for subsample in search_params['subsample']:
            print('subsample: %s' % subsample)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model1 = XGBRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                y_train_pred1 = model1.predict(X_train[X_columns])
                y_verify_pred1 = model1.predict(X_verify[X_columns])
                
                model2 = XGBRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                y_train_pred2 = model2.predict(X_train[X_columns])
                y_verify_pred2= model2.predict(X_verify[X_columns])

                X_train['uplift'] = y_train_pred1 - y_train_pred2
                X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                #train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                #verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                
                # 连续y计算auuc score
                train_qini_auc_score = auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                verify_qini_auc_score = auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result,\
                             {'learning_rate': learning_rate,'n_estimators': n_estimators, \
                              'subsample':subsample, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.005
# n_estimators: 30
# subsample: 0.52
# max_depth: 20
# train_qini_auc_score: 2.3893494095825965, verify_qini_auc_score: 0.7639337495923357
# monotonicity_train: 0.7006490497453708, monotonicity_verify: 0.709090909090909
# [{'auc_score': 0.7639337495923357, 'monotonicity': 0.709090909090909, 'params': {'learning_rate': 0.005, 'n_estimators': 30, 'subsample': 0.52, 'max_depth': 20}}]

# %%
'''
best_params:
learning_rate: 0.01
n_estimators: 40
subsample: 0.4
max_depth: 2
'''
# Out:
# '\nbest_params:\nlearning_rate: 0.01\nn_estimators: 40\nsubsample: 0.4\nmax_depth: 2\n'

# %%
# 模型保存
dump(model1, 'result/womens_spend/xgb_model1.joblib')
dump(model2, 'result/womens_spend/xgb_model2.joblib')
# Out:
# ['result/womens_spend/xgb_model2.joblib']

# %%
#plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
#plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
#print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_train))
plot_gain(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_verify))
print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
print(auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
# Out:
# 2.3893494095825965
# 0.7639337495923357

# %%
#plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
#                          strategy='by_group', kind='bar')
new_df_train = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10)
# Out:
#    uplift_score     type
# 0     -0.317821   actual
# 1     -1.015577   actual
# 2      1.126735   actual
# 3      0.657165   actual
# 4      0.365295   actual
# 5      0.456288   actual
# 6      0.915146   actual
# 7      0.587764   actual
# 8      1.210762   actual
# 9      1.355960   actual
# 0     -0.531957  predict
# 1     -0.001610  predict
# 2     -0.000957  predict
# 3     -0.000678  predict
# 4     -0.000461  predict
# 5     -0.000254  predict
# 6      0.000041  predict
# 7      0.000486  predict
# 8      0.013254  predict
# 9      0.954172  predict

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.002,0.003,0.004], 'n_estimators':[60,70,80], 
#                'subsample':[0.4,0.45,0.5], 'max_depth': [5]}

search_params = {'learning_rate': [0.002], 'n_estimators':[70], 
                'subsample':[0.5], 'max_depth': [5]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for subsample in search_params['subsample']:
            print('subsample: %s' % subsample)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model1 = CatBoostRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                y_train_pred1 = model1.predict(X_train[X_columns])
                y_verify_pred1 = model1.predict(X_verify[X_columns])
                
                model2 = CatBoostRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                y_train_pred2 = model2.predict(X_train[X_columns])
                y_verify_pred2= model2.predict(X_verify[X_columns])

                X_train['uplift'] = y_train_pred1 - y_train_pred2
                X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                #train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                #verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                
                # 连续y计算auuc score
                train_qini_auc_score = auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                verify_qini_auc_score = auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                              {'learning_rate':learning_rate,'n_estimators': n_estimators, \
                              'subsample':subsample, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.002
# n_estimators: 70
# subsample: 0.5
# max_depth: 5
# 0:	learn: 15.5431696	total: 54ms	remaining: 3.73s
# 1:	learn: 15.5425425	total: 55.8ms	remaining: 1.9s
# 2:	learn: 15.5422684	total: 57.9ms	remaining: 1.29s
# 3:	learn: 15.5416092	total: 59.8ms	remaining: 987ms
# 4:	learn: 15.5411384	total: 61.5ms	remaining: 799ms
# 5:	learn: 15.5400386	total: 62.8ms	remaining: 670ms
# 6:	learn: 15.5392180	total: 64.5ms	remaining: 580ms
# 7:	learn: 15.5386436	total: 66ms	remaining: 512ms
# 8:	learn: 15.5373890	total: 67.6ms	remaining: 458ms
# 9:	learn: 15.5363522	total: 69.2ms	remaining: 415ms
# 10:	learn: 15.5353145	total: 70.8ms	remaining: 380ms
# 11:	learn: 15.5346349	total: 72.3ms	remaining: 350ms
# 12:	learn: 15.5333794	total: 73.9ms	remaining: 324ms
# 13:	learn: 15.5323374	total: 75.3ms	remaining: 301ms
# 14:	learn: 15.5310928	total: 76.7ms	remaining: 281ms
# 15:	learn: 15.5298432	total: 77.9ms	remaining: 263ms
# 16:	learn: 15.5285957	total: 79.4ms	remaining: 248ms
# 17:	learn: 15.5275827	total: 81.1ms	remaining: 234ms
# 18:	learn: 15.5270120	total: 82.4ms	remaining: 221ms
# 19:	learn: 15.5268913	total: 84.1ms	remaining: 210ms
# 20:	learn: 15.5258924	total: 85.5ms	remaining: 199ms
# 21:	learn: 15.5254535	total: 87.3ms	remaining: 190ms
# 22:	learn: 15.5244619	total: 89ms	remaining: 182ms
# 23:	learn: 15.5242557	total: 90.5ms	remaining: 174ms
# 24:	learn: 15.5232507	total: 91.9ms	remaining: 166ms
# 25:	learn: 15.5220149	total: 93.4ms	remaining: 158ms
# 26:	learn: 15.5211969	total: 95.2ms	remaining: 152ms
# 27:	learn: 15.5199693	total: 96.8ms	remaining: 145ms
# 28:	learn: 15.5189518	total: 98.2ms	remaining: 139ms
# 29:	learn: 15.5184579	total: 100ms	remaining: 133ms
# 30:	learn: 15.5172294	total: 102ms	remaining: 128ms
# 31:	learn: 15.5167666	total: 103ms	remaining: 123ms
# 32:	learn: 15.5155458	total: 105ms	remaining: 118ms
# 33:	learn: 15.5146876	total: 107ms	remaining: 113ms
# 34:	learn: 15.5138501	total: 108ms	remaining: 108ms
# 35:	learn: 15.5137162	total: 109ms	remaining: 103ms
# 36:	learn: 15.5131638	total: 110ms	remaining: 98.3ms
# 37:	learn: 15.5119433	total: 111ms	remaining: 93.8ms
# 38:	learn: 15.5107231	total: 113ms	remaining: 89.8ms
# 39:	learn: 15.5095049	total: 114ms	remaining: 85.6ms
# 40:	learn: 15.5086973	total: 115ms	remaining: 81.6ms
# 41:	learn: 15.5074820	total: 116ms	remaining: 77.6ms
# 42:	learn: 15.5070687	total: 118ms	remaining: 73.9ms
# 43:	learn: 15.5058629	total: 119ms	remaining: 70.3ms
# 44:	learn: 15.5046540	total: 120ms	remaining: 66.9ms
# 45:	learn: 15.5034454	total: 122ms	remaining: 63.5ms
# 46:	learn: 15.5022456	total: 123ms	remaining: 60.3ms
# 47:	learn: 15.5019837	total: 125ms	remaining: 57.1ms
# 48:	learn: 15.5014276	total: 126ms	remaining: 53.9ms
# 49:	learn: 15.5010029	total: 127ms	remaining: 50.7ms
# 50:	learn: 15.4998014	total: 128ms	remaining: 47.7ms
# 51:	learn: 15.4987681	total: 129ms	remaining: 44.8ms
# 52:	learn: 15.4975685	total: 130ms	remaining: 41.9ms
# 53:	learn: 15.4963708	total: 132ms	remaining: 39ms
# 54:	learn: 15.4957314	total: 133ms	remaining: 36.2ms
# 55:	learn: 15.4945366	total: 134ms	remaining: 33.5ms
# 56:	learn: 15.4933454	total: 135ms	remaining: 30.8ms
# 57:	learn: 15.4921562	total: 136ms	remaining: 28.2ms
# 58:	learn: 15.4909690	total: 138ms	remaining: 25.7ms
# 59:	learn: 15.4897820	total: 139ms	remaining: 23.1ms
# 60:	learn: 15.4885970	total: 140ms	remaining: 20.6ms
# 61:	learn: 15.4874140	total: 141ms	remaining: 18.2ms
# 62:	learn: 15.4862329	total: 142ms	remaining: 15.8ms
# 63:	learn: 15.4850538	total: 143ms	remaining: 13.5ms
# 64:	learn: 15.4838784	total: 145ms	remaining: 11.1ms
# 65:	learn: 15.4827032	total: 146ms	remaining: 8.85ms
# 66:	learn: 15.4815366	total: 147ms	remaining: 6.59ms
# 67:	learn: 15.4803719	total: 148ms	remaining: 4.36ms
# 68:	learn: 15.4792025	total: 150ms	remaining: 2.17ms
# 69:	learn: 15.4780418	total: 151ms	remaining: 0us
# 0:	learn: 11.6810896	total: 1.66ms	remaining: 114ms
# 1:	learn: 11.6810148	total: 2.89ms	remaining: 98.3ms
# 2:	learn: 11.6808445	total: 4.01ms	remaining: 89.5ms
# 3:	learn: 11.6807339	total: 5.22ms	remaining: 86.2ms
# 4:	learn: 11.6806305	total: 6.54ms	remaining: 85ms
# 5:	learn: 11.6805445	total: 8.37ms	remaining: 89.3ms
# 6:	learn: 11.6804507	total: 9.96ms	remaining: 89.6ms
# 7:	learn: 11.6801176	total: 11.5ms	remaining: 89.3ms
# 8:	learn: 11.6799838	total: 13.1ms	remaining: 88.5ms
# 9:	learn: 11.6799079	total: 14.4ms	remaining: 86.3ms
# 10:	learn: 11.6798052	total: 15.7ms	remaining: 84.4ms
# 11:	learn: 11.6796069	total: 17ms	remaining: 82.4ms
# 12:	learn: 11.6795527	total: 18.6ms	remaining: 81.5ms
# 13:	learn: 11.6794277	total: 19.8ms	remaining: 79.3ms
# 14:	learn: 11.6792906	total: 21.3ms	remaining: 78.2ms
# 15:	learn: 11.6791615	total: 22.9ms	remaining: 77.2ms
# 16:	learn: 11.6791014	total: 24.2ms	remaining: 75.5ms
# 17:	learn: 11.6790200	total: 25.7ms	remaining: 74.3ms
# 18:	learn: 11.6788812	total: 27.3ms	remaining: 73.2ms
# 19:	learn: 11.6788257	total: 28.6ms	remaining: 71.5ms
# 20:	learn: 11.6787255	total: 29.9ms	remaining: 69.8ms
# 21:	learn: 11.6786643	total: 31.3ms	remaining: 68.4ms
# 22:	learn: 11.6785661	total: 32.8ms	remaining: 67.1ms
# 23:	learn: 11.6785271	total: 34.3ms	remaining: 65.8ms
# 24:	learn: 11.6784027	total: 36.1ms	remaining: 65ms
# 25:	learn: 11.6783338	total: 38.2ms	remaining: 64.6ms
# 26:	learn: 11.6782473	total: 40.2ms	remaining: 64.1ms
# 27:	learn: 11.6780355	total: 42.1ms	remaining: 63.2ms
# 28:	learn: 11.6779682	total: 43.5ms	remaining: 61.5ms
# 29:	learn: 11.6778901	total: 44.8ms	remaining: 59.7ms
# 30:	learn: 11.6778115	total: 46.5ms	remaining: 58.5ms
# 31:	learn: 11.6775793	total: 48.2ms	remaining: 57.2ms
# 32:	learn: 11.6775132	total: 50ms	remaining: 56ms
# 33:	learn: 11.6774388	total: 51.6ms	remaining: 54.6ms
# 34:	learn: 11.6773639	total: 53ms	remaining: 53ms
# 35:	learn: 11.6773255	total: 54.7ms	remaining: 51.7ms
# 36:	learn: 11.6772821	total: 56.3ms	remaining: 50.2ms
# 37:	learn: 11.6772161	total: 57.9ms	remaining: 48.7ms
# 38:	learn: 11.6771368	total: 59.2ms	remaining: 47.1ms
# 39:	learn: 11.6770392	total: 60.8ms	remaining: 45.6ms
# 40:	learn: 11.6769728	total: 62ms	remaining: 43.8ms
# 41:	learn: 11.6767093	total: 63.4ms	remaining: 42.3ms
# 42:	learn: 11.6764979	total: 64.7ms	remaining: 40.6ms
# 43:	learn: 11.6763811	total: 66ms	remaining: 39ms
# 44:	learn: 11.6761955	total: 67.2ms	remaining: 37.4ms
# 45:	learn: 11.6760410	total: 68.3ms	remaining: 35.7ms
# 46:	learn: 11.6759762	total: 69.6ms	remaining: 34ms
# 47:	learn: 11.6758894	total: 70.8ms	remaining: 32.4ms
# 48:	learn: 11.6757635	total: 72.1ms	remaining: 30.9ms
# 49:	learn: 11.6756644	total: 73.3ms	remaining: 29.3ms
# 50:	learn: 11.6755936	total: 74.4ms	remaining: 27.7ms
# 51:	learn: 11.6755407	total: 75.5ms	remaining: 26.1ms
# 52:	learn: 11.6754900	total: 76.6ms	remaining: 24.6ms
# 53:	learn: 11.6754436	total: 77.8ms	remaining: 23.1ms
# 54:	learn: 11.6753430	total: 79ms	remaining: 21.5ms
# 55:	learn: 11.6752718	total: 80.4ms	remaining: 20.1ms
# 56:	learn: 11.6751865	total: 81.6ms	remaining: 18.6ms
# 57:	learn: 11.6751392	total: 82.7ms	remaining: 17.1ms
# 58:	learn: 11.6749560	total: 84ms	remaining: 15.7ms
# 59:	learn: 11.6748995	total: 85.3ms	remaining: 14.2ms
# 60:	learn: 11.6748316	total: 86.5ms	remaining: 12.8ms
# 61:	learn: 11.6744864	total: 87.8ms	remaining: 11.3ms
# 62:	learn: 11.6744487	total: 89ms	remaining: 9.89ms
# 63:	learn: 11.6743350	total: 90.1ms	remaining: 8.44ms
# 64:	learn: 11.6741755	total: 91.2ms	remaining: 7.01ms
# 65:	learn: 11.6740521	total: 92.3ms	remaining: 5.59ms
# 66:	learn: 11.6737914	total: 93.3ms	remaining: 4.18ms
# 67:	learn: 11.6737081	total: 94.6ms	remaining: 2.78ms
# 68:	learn: 11.6736609	total: 95.8ms	remaining: 1.39ms
# 69:	learn: 11.6734921	total: 96.9ms	remaining: 0us
# train_qini_auc_score: 1.1210197635013686, verify_qini_auc_score: 1.0737590748519186
# monotonicity_train: 0.6727272727272726, monotonicity_verify: 0.9030303030303028
# [{'auc_score': 1.0737590748519186, 'monotonicity': 0.9030303030303028, 'params': {'learning_rate': 0.002, 'n_estimators': 70, 'subsample': 0.5, 'max_depth': 5}}]

# %%
# 模型保存
dump(model1, 'result/womens_spend/cat_boost_model1.joblib')
dump(model2, 'result/womens_spend/cat_boost_model2.joblib')
# Out:
# ['result/womens_spend/cat_boost_model2.joblib']

# %%
# best_params
#{'learning_rate': 0.02, 'n_estimators': 50, 'subsample': 0.4, 'max_depth': 2}

# %%
#plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
#plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
#print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_train))
plot_gain(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_verify))
print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
print(auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
# Out:
# 1.1210197635013686
# 1.0737590748519186

# %%
#plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
#                          strategy='by_group', kind='bar')
new_df_train = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10)
# Out:
#    uplift_score     type
# 0     -1.868874   actual
# 1     -0.602529   actual
# 2     -0.468695   actual
# 3      0.351355   actual
# 4      0.935007   actual
# 5      1.770863   actual
# 6      0.522232   actual
# 7      1.080473   actual
# 8      1.179448   actual
# 9      2.544385   actual
# 0      0.370941  predict
# 1      0.428744  predict
# 2      0.453093  predict
# 3      0.469565  predict
# 4      0.481802  predict
# 5      0.492547  predict
# 6      0.502704  predict
# 7      0.512966  predict
# 8      0.534920  predict
# 9      0.710778  predict

# %% [markdown]
# #### Part3 因果森林

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'n_estimators':[40,44,48], 
#                'min_samples_leaf': [1], 'max_depth': [6,8,10],
#                'max_samples': [0.3]}

search_params = {
    'n_estimators': [44],
    'min_samples_leaf': [1],
    'max_depth': [8],
    'max_samples': [0.3]
}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for max_samples in search_params['max_samples']:
    print('max_samples: %s' % max_samples)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for min_samples_leaf in search_params['min_samples_leaf']:
            print('min_samples_leaf: %s' % min_samples_leaf)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model = CausalForestDML(criterion='het', 
                                max_depth=max_depth,
                                n_estimators=n_estimators,  
                                min_samples_leaf=min_samples_leaf, 
                                max_samples=max_samples,
                                discrete_treatment=True,
                                honest=True,
                                inference=True,
                                cv=5)
                model.fit(X_train[y_columns], X_train[[treatment]], X=X_train[X_columns], W=None, cache_values=True)
                X_train['uplift'] = model.effect(X_train[X_columns])
                X_verify['uplift'] = model.effect(X_verify[X_columns])
                    
                #train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                #verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                
                # 连续y计算auuc score
                train_qini_auc_score = auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                verify_qini_auc_score = auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift']
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                             {'max_samples':max_samples,'n_estimators': n_estimators, \
                              'min_samples_leaf':min_samples_leaf, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# max_samples: 0.3
# n_estimators: 44
# min_samples_leaf: 1
# max_depth: 8
# train_qini_auc_score: 1.6507442537430768, verify_qini_auc_score: 1.0317942919667338
# monotonicity_train: 0.8181818181818182, monotonicity_verify: 0.7333333333333332
# [{'auc_score': 1.0317942919667338, 'monotonicity': 0.7333333333333332, 'params': {'max_samples': 0.3, 'n_estimators': 44, 'min_samples_leaf': 1, 'max_depth': 8}}]

# %%
# 模型保存
dump(model, 'result/womens_spend/causal_forest_model.joblib')
# Out:
# ['result/womens_spend/causal_forest_model.joblib']

# %%
#plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
#plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
#print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_train))
plot_gain(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_verify))
print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
print(auuc_score(X_verify[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)['uplift'])
# Out:
# 1.6507442537430768
# 1.0317942919667338

# %%
#plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
#                          strategy='by_group', kind='bar')
new_df_train = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10)
# Out:
#    uplift_score     type
# 0     -1.735023   actual
# 1      0.295972   actual
# 2     -0.215444   actual
# 3     -0.058805   actual
# 4     -0.633684   actual
# 5      0.059399   actual
# 6      2.206054   actual
# 7      3.064496   actual
# 8      1.988215   actual
# 9      0.591732   actual
# 0     -1.439463  predict
# 1     -0.405704  predict
# 2     -0.099668  predict
# 3      0.089287  predict
# 4      0.220045  predict
# 5      0.347901  predict
# 6      0.514615  predict
# 7      0.750695  predict
# 8      1.182593  predict
# 9      3.257576  predict

# %%
# 连续变量
#plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)
#auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)

# %%
## 多模型比较
gbdt_model1 = load('result/womens_spend/gbdt_model1.joblib')
gbdt_model2 = load('result/womens_spend/gbdt_model2.joblib')

X_test['gbdt_uplift'] = gbdt_model1.predict(X_test[X_columns]) - gbdt_model2.predict(X_test[X_columns])

xgb_model1 = load('result/womens_spend/xgb_model1.joblib')
xgb_model2 = load('result/womens_spend/xgb_model2.joblib')

X_test['xgb_uplift'] = xgb_model1.predict(X_test[X_columns]) - xgb_model2.predict(X_test[X_columns])

cat_boost_model1 = load('result/womens_spend/cat_boost_model1.joblib')
cat_boost_model2 = load('result/womens_spend/cat_boost_model2.joblib')

X_test['cat_boost_uplift'] = cat_boost_model1.predict(X_test[X_columns]) - cat_boost_model2.predict(X_test[X_columns])

causal_forest_model = load('result/womens_spend/causal_forest_model.joblib')
X_test['causal_forest_uplift'] = causal_forest_model.effect(X_test[X_columns])
#X_test['causal_forest_uplift'] = causal_forest_model.const_marginal_effect(X_test[X_columns])

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
#plot_qini_curve(X_test[y_columns], X_test['gbdt_uplift'], X_test[treatment], perfect=False, name='GBDT', ax=ax)
#plot_qini_curve(X_test[y_columns], X_test['xgb_uplift'], X_test[treatment], perfect=False, name='XGB', ax=ax)
#plot_qini_curve(X_test[y_columns], X_test['cat_boost_uplift'], X_test[treatment], perfect=False, name='CAT_BOOST', ax=ax)
#plot_qini_curve(X_test[y_columns], X_test['causal_forest_uplift'], X_test[treatment], perfect=False, name='CAUSAL_FOREST', ax=ax)
#print('GBDT QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['gbdt_uplift'], X_test[treatment]))
#print('XGB QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['xgb_uplift'], X_test[treatment]))
#print('CAT BOOST QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['cat_boost_uplift'], X_test[treatment]))
#print('CAUSAL FOREST SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['causal_forest_uplift'], X_test[treatment]))
plot_gain(X_test[[y_columns, treatment, 'gbdt_uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_test))
plot_gain(X_test[[y_columns, treatment, 'xgb_uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_test))
plot_gain(X_test[[y_columns, treatment, 'cat_boost_uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_test))
plot_gain(X_test[[y_columns, treatment, 'causal_forest_uplift']], outcome_col=y_columns, treatment_col=treatment, n=len(X_test))
print('GBDT QINI SCORE: %s' % auuc_score(X_test[[y_columns, treatment, 'gbdt_uplift']], outcome_col=y_columns, treatment_col=treatment)['gbdt_uplift'])
print('XGB QINI SCORE: %s' % auuc_score(X_test[[y_columns, treatment, 'xgb_uplift']], outcome_col=y_columns, treatment_col=treatment)['xgb_uplift'])
print('CAT BOOST QINI SCORE: %s' % auuc_score(X_test[[y_columns, treatment, 'cat_boost_uplift']], outcome_col=y_columns, treatment_col=treatment)['cat_boost_uplift'])
print('CAUSAL FOREST QINI SCORE: %s' % auuc_score(X_test[[y_columns, treatment, 'causal_forest_uplift']], outcome_col=y_columns, treatment_col=treatment)['causal_forest_uplift'])
# Out:
# GBDT QINI SCORE: 0.41060404624153973
# XGB QINI SCORE: 0.6869623314447282
# CAT BOOST QINI SCORE: 0.7262056375190274
# CAUSAL FOREST QINI SCORE: 0.42215552758656866

# %% [markdown]
# ## 第四部分：收益回归
# uplift排名前15%的人群收益和uplift排名后15%的人群收益（也用来衡量偏序关系寻优的效果）

# %%
bottom = np.percentile(X_test['cat_boost_uplift'], 15.6)
up = np.percentile(X_test['cat_boost_uplift'], 100-15.6)

# %%
up
# Out:
# 0.5339847388706739

# %%
good = X_test[X_test['cat_boost_uplift']>=up]
bad = X_test[X_test['cat_boost_uplift']<=bottom]
print(len(good))
print(len(bad))
print(len(X_test))
# Out:
# 2001
# 1999
# 12809

# %%
good_exp = good[good[treatment]==1]
good_base = good[good[treatment]==0]
print('good人群对visit的处理效应：%s' % (good_exp['visit'].mean() - good_base['visit'].mean()))
print('good人群对conversion的处理效应：%s' % (good_exp['conversion'].mean() - good_base['conversion'].mean()))
print('good人群对spend的处理效应：%s' % (good_exp['spend'].mean() - good_base['spend'].mean()))
# Out:
# good人群对visit的处理效应：0.032343015391255184
# good人群对conversion的处理效应：0.006114142651340015
# good人群对spend的处理效应：0.8032515050581542

# %%
bad_exp = bad[bad[treatment]==1]
bad_base = bad[bad[treatment]==0]
print('bad人群对visit的处理效应：%s' % (bad_exp['visit'].mean() - bad_base['visit'].mean()))
print('bad人群对conversion的处理效应：%s' % (bad_exp['conversion'].mean() - bad_base['conversion'].mean()))
print('bad人群对spend的处理效应：%s' % (bad_exp['spend'].mean() - bad_base['spend'].mean()))
# Out:
# bad人群对visit的处理效应：0.052380150679742415
# bad人群对conversion的处理效应：0.006479750029562732
# bad人群对spend的处理效应：0.8001738489073815

# %% [markdown]
# ## 第五部分：提炼人群共性

# %%
label = 'causal_forest_uplift'

search_params = {'criterion': ['mse'],
                'max_depth': [9,10,11,None],
                #'max_features': ['sqrt','auto','log2'],
                'max_features': ['auto'],
                'min_impurity_decrease': [0]}

tree_train, tree_test = train_test_split(X_test, test_size=0.3, random_state=0)

best_score = 0
best_params = {}
best_model = None

for criterion in search_params['criterion']:
    print('criterion: %s' % criterion)
    for max_depth in search_params['max_depth']:
        print('max_depth: %s' % max_depth)
        for max_features in search_params['max_features']:
            print('max_features: %s' % max_features)
            for min_impurity_decrease in search_params['min_impurity_decrease']:
                print('min_impurity_decrease: %s' % min_impurity_decrease)
                tree_model = DecisionTreeRegressor(criterion=criterion,
                                                 splitter='best',
                                                 max_depth=max_depth,
                                                 min_samples_split=2,
                                                 min_samples_leaf=1,
                                                 min_weight_fraction_leaf=0,
                                                 max_features=max_features,
                                                 random_state=None,
                                                 max_leaf_nodes=None,
                                                 min_impurity_decrease=min_impurity_decrease)
                tree_model.fit(tree_train[X_columns], tree_train[label])
                
                tree_train_score = tree_model.score(tree_train[X_columns], tree_train[label])
                tree_test_score = tree_model.score(tree_test[X_columns], tree_test[label])
                
                print('tree_train_score: %s, tree_test_score: %s' % (tree_train_score, tree_test_score))
                
                if tree_test_score > best_score:
                    best_score = tree_test_score
                    best_params = {'criterion': criterion, 'max_depth': max_depth, 
                                  'max_features': max_features, 'min_impurity_decrease': min_impurity_decrease}
                    best_model = tree_model
    
print(best_score)
print(best_params)
# Out:
# criterion: mse
# max_depth: 9
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 0.9520780198496085, tree_test_score: 0.937157228189353
# max_depth: 10
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 0.9749553021348409, tree_test_score: 0.9585057038110103
# max_depth: 11
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 0.988067688727908, tree_test_score: 0.9700824293593749
# max_depth: None
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 1.0, tree_test_score: 0.978846536180123
# 0.978846536180123
# {'criterion': 'mse', 'max_depth': None, 'max_features': 'auto', 'min_impurity_decrease': 0}

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(best_model, 
                   feature_names=X_columns,  
                   filled=True)
