# %%
#from sklift.datasets import fetch_hillstrom
import pandas as pd
import numpy as np 
from scipy import stats
from econml.dml import CausalForestDML
from sklearn.linear_model import LassoCV
from sklearn.metrics import classification_report
from causalml.metrics import plot_gain,auuc_score
from scipy.stats import spearmanr
from sklearn.model_selection import (
    RandomizedSearchCV,GridSearchCV,cross_val_score,train_test_split,GroupKFold,
    StratifiedShuffleSplit,cross_validate)
from lightgbm import LGBMClassifier
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn import tree

from sklift.metrics import uplift_at_k
from sklift.viz import plot_uplift_preds
from sklift.models import SoloModel,ClassTransformation,TwoModels
from sklift.metrics import uplift_by_percentile
from sklift.viz import plot_uplift_by_percentile
from sklift.viz import plot_qini_curve,plot_uplift_curve
from sklift.metrics import qini_auc_score,uplift_auc_score

from causalml.inference.meta import BaseXRegressor, BaseRRegressor, BaseSRegressor, BaseTRegressor
from causalml.dataset import *
from causalml.metrics import *

import scipy
import seaborn as sns
import time
import warnings
from matplotlib import pyplot as plt
from joblib import dump, load
warnings.filterwarnings("ignore")
# %matplotlib inline

# %% [markdown]
# 背景：
# 这是 MineThatData 电子邮件分析和数据挖掘挑战数据集的副本。
# 该数据集包含 64,000 名在十二个月内最后一次购买的客户。 客户参与了电子邮件测试。
# 1/3 被随机选择接收以男士商品为特色的电子邮件活动。
# 1/3 被随机选择接收以女性商品为特色的电子邮件活动。
# 1/3 被随机选择不接收电子邮件活动。
# 在电子邮件活动之后的两周内，对结果进行了跟踪。 你的工作是告诉全世界男士或女士电子邮件活动是否成功。
#
# 数据集由 Kevin Hillstorm 提供。 Kevin 是 MineThatData 的总裁，该公司是一家帮助 CEO 了解客户、广告、产品、品牌和渠道之间复杂关系的咨询公司。

# %%
data = pd.read_csv('../hillstrom_data/mens_exp_data.csv', sep='\t')
data.sample()
# Out:
#        recency  history_segment  history  mens  womens  zip_code  newbie  \
# 19142        1               50    55.64     0       1         3       0
#
#        channel_phone  channel_web  segment_mens  segment_womens  visit  \
# 19142              1            0             1               0      0
#
#        conversion  spend  history_norm
# 19142           0    0.0       4.06587

# %%
len(data)
# Out:
# 42613

# %%
data.describe()
# Out:
#             recency  history_segment       history          mens  \
# count  42613.000000     42613.000000  42613.000000  42613.000000
# mean       5.761669       240.419590    241.859315      0.552085
# std        3.505422       231.596262    256.574723      0.497286
# min        1.000000        50.000000     29.990000      0.000000
# 25%        2.000000        50.000000     64.500000      0.000000
# 50%        6.000000       150.000000    157.000000      1.000000
# 75%        9.000000       275.000000    325.210000      1.000000
# max       12.000000      1000.000000   3345.930000      1.000000
#
#              womens      zip_code        newbie  channel_phone   channel_web  \
# count  42613.000000  42613.000000  42613.000000   42613.000000  42613.000000
# mean       0.549527      2.251637      0.501748       0.557342      0.564288
# std        0.497547      0.698470      0.500003       0.496707      0.495856
# min        0.000000      1.000000      0.000000       0.000000      0.000000
# 25%        0.000000      2.000000      0.000000       0.000000      0.000000
# 50%        1.000000      2.000000      1.000000       1.000000      1.000000
# 75%        1.000000      3.000000      1.000000       1.000000      1.000000
# max        1.000000      3.000000      1.000000       1.000000      1.000000
#
#        segment_mens  segment_womens         visit    conversion         spend  \
# count  42613.000000         42613.0  42613.000000  42613.000000  42613.000000
# mean       0.500012             0.0      0.144463      0.009129      1.037712
# std        0.500006             0.0      0.351563      0.095108     14.996469
# min        0.000000             0.0      0.000000      0.000000      0.000000
# 25%        0.000000             0.0      0.000000      0.000000      0.000000
# 50%        1.000000             0.0      0.000000      0.000000      0.000000
# 75%        1.000000             0.0      0.000000      0.000000      0.000000
# max        1.000000             0.0      1.000000      1.000000    499.000000
#
#        history_norm
# count  42613.000000
# mean       5.069081
# std        1.059722
# min        3.434457
# 25%        4.217165
# 50%        5.130739
# 75%        5.882104
# max        8.308546

# %%
data
# Out:
#        recency  history_segment  history  mens  womens  zip_code  newbie  \
# 0            9              625   675.83     1       0         1       1
# 1            9              625   675.07     1       1         1       1
# 2            2              150   101.64     0       1         3       0
# 3            5               50    29.99     1       0         2       0
# 4            9              150   112.35     1       0         1       0
# ...        ...              ...      ...   ...     ...       ...     ...
# 42608        3              425   487.10     0       1         2       1
# 42609        4              150   125.53     0       1         1       1
# 42610        2               50    83.03     0       1         3       0
# 42611        1               50    79.70     1       0         2       1
# 42612        6               50    80.02     0       1         2       0
#
#        channel_phone  channel_web  segment_mens  segment_womens  visit  \
# 0                  0            1             1               0      0
# 1                  1            0             1               0      0
# 2                  0            1             1               0      1
# 3                  1            0             1               0      0
# 4                  0            1             1               0      0
# ...              ...          ...           ...             ...    ...
# 42608              1            0             0               0      0
# 42609              1            0             0               0      0
# 42610              1            0             0               0      0
# 42611              0            1             0               0      0
# 42612              1            0             0               0      0
#
#        conversion  spend  history_norm
# 0               0    0.0      6.640003
# 1               0    0.0      6.638835
# 2               0    0.0      4.683617
# 3               0    0.0      3.434457
# 4               0    0.0      4.786536
# ...           ...    ...           ...
# 42608           0    0.0      6.300304
# 42609           0    0.0      4.900562
# 42610           0    0.0      4.476036
# 42611           0    0.0      4.434052
# 42612           0    0.0      4.438161
#
# [42613 rows x 15 columns]

# %%
treatment = 'segment_mens'
## 划分训练集、验证集、测试集
X_train_exp, X_test_exp = train_test_split(data[data[treatment]==1], test_size=0.3, random_state=1)
X_train_exp, X_verify_exp = train_test_split(X_train_exp, test_size=0.3, random_state=1)

X_train_base, X_test_base = train_test_split(data[data[treatment]==0], test_size=0.3, random_state=1)
X_train_base, X_verify_base = train_test_split(X_train_base, test_size=0.3, random_state=1)

X_train = X_train_exp.append(X_train_base)
X_verify = X_verify_exp.append(X_verify_base)
X_test = X_test_exp.append(X_test_base)

# %%
X_columns = ['recency', 'history_segment', 'history_norm', 'history', 'mens', 'womens', 'zip_code',
       'newbie', 'channel_phone', 'channel_web']
y_columns = 'visit'

# %%
f1_micro = cross_val_score(
    X=data[X_columns],
    y=data[treatment],
    estimator= LGBMClassifier(random_state=42, n_jobs=-1),
    scoring='f1_micro', 
    cv=3)
print(f'F1 micro {f1_micro.mean():.2f}')
# Out:
# F1 micro 0.50

# %% [markdown]
# ## 第三部分：建模（尝试多种模型）和模型评价
# 可用模型：
# * two-model：（1）任意的机器学习分类/回归模型；（2）封装好的模型MetaLearner
# * one-model：（1）任意的机器学习分类/回归模型；（2）封装好的模型MetaLearner
# * 标签转换模型（适用于visit和conversion）：（1）标签转换后，任意的机器学习分类模型。（2）封装好的模型：pylift.TransformedOutcome
# * 因果森林：（1）简单因果森林 causalml；（2）econml
#
# 模型评价：
# * mse
# * auuc score及图形
# * 单调性分数
# * 柱形图

# %%
def get_cuts_mean(df, cuts):
    cuts_mean = []
    for i in range(0, len(cuts)):
        if i == 0:
            mean_value = df[df['uplift'] > cuts[i]]['uplift'].mean()
        else:
            mean_value = df[(df['uplift'] <= cuts[i-1]) & (df['uplift'] > cuts[i])]['uplift'].mean()
        cuts_mean.append(mean_value)
    mean_value = df[df['uplift'] <= cuts[-1]]['uplift'].mean()
    cuts_mean.append(mean_value)
    return cuts_mean

def get_uplift_cut(x, cuts):
    percent = scipy.stats.percentileofscore(cuts, x)/100
    index = int(percent*(len(cuts)+1)) if int(percent*(len(cuts)+1)) <= len(cuts) else len(cuts)
    return len(cuts)-index

def plot_uplift(df, bins=10, treatment='treatment', metric='label', is_plot=True):
    cuts = [np.percentile(df['uplift'], i) for i in range(100-int(100/bins),0 , -int(100/bins))]
    cuts_mean = get_cuts_mean(df,cuts)
    df['pre_uplift_score'] = df['uplift'].apply(lambda x: cuts_mean[get_uplift_cut(x, cuts)])
    df2 = df.groupby([treatment, 'pre_uplift_score'])[metric].mean().reset_index()
    act_df = pd.DataFrame()
    act_df['uplift_score'] = df2[df2[treatment]==1].reset_index()[metric] - df2[df2[treatment]==0].reset_index()[metric]
    act_df['type'] = 'actual'
    pre_df = pd.DataFrame()
    pre_df['uplift_score'] = df2[df2[treatment]==0]['pre_uplift_score']
    pre_df['type'] = 'predict'
    new_df = act_df.append(pre_df)
    if is_plot:
        print(new_df)
        sns.set(rc={'figure.figsize':(11.7,8.27)})
        #sns.barplot(x=new_df.index, y='uplift_score', hue='type', data=new_df, order=[i for i in range(bins-1,-1,-1)])
        sns.barplot(x=new_df.index, y='uplift_score', hue='type', data=new_df, order=[i for i in range(bins-1,-1,-1)])
    return new_df

# %% [markdown]
# #### Part1: two model & one model
# * two model是每个treatment各建立一个模型，模型之间计算delta作为预测的CATE
# * one model是将treatment作为一个特征，跟其他特征一起训练，同一个模型不同的Treatment值代入后计算delta作为预测的CATE

# %%
def pareto_result(auc_score, monotonicity, old_result, params=None):
    for i in range(len(old_result)):
        if auc_score > old_result[i]['auc_score'] and monotonicity > old_result[i]['monotonicity']:
            old_result[i]['auc_score'] = auc_score
            old_result[i]['monotonicity'] = monotonicity
            old_result[i]['params'] = params
            return
        
        if auc_score <= old_result[i]['auc_score'] and monotonicity <= old_result[i]['monotonicity']:
            return 
        
    #old_result.append({'auc_score': auc_score, 'monotonicity': monotonicity, 'params':params})
    return

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.003, 0.005, 0.01, 0.015, 0.02], 'n_estimators':[50,60,70], 
#                 'criterion':['friedman_mse'],
#                'min_samples_leaf': [1], 'max_depth': [5]}

search_params = {'learning_rate': [0.005], 'n_estimators':[60], 
                'criterion':['friedman_mse'],
                'min_samples_leaf': [1], 'max_depth': [5]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for criterion in search_params['criterion']:
            print('criterion: %s' % criterion)
            for min_samples_leaf in search_params['min_samples_leaf']:
                print('min_samples_leaf: %s' % min_samples_leaf)
                for max_depth in search_params['max_depth']:
                    print('max_depth: %s' % max_depth)

                    model1 = GradientBoostingRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      criterion=criterion, min_samples_leaf=min_samples_leaf,
                                                      max_depth=max_depth) 
                    model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                    y_train_pred1 = model1.predict(X_train[X_columns])
                    y_verify_pred1 = model1.predict(X_verify[X_columns])

                    model2 = GradientBoostingRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      criterion=criterion, min_samples_leaf=min_samples_leaf,
                                                      max_depth=max_depth) 
                    model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                    y_train_pred2 = model2.predict(X_train[X_columns])
                    y_verify_pred2= model2.predict(X_verify[X_columns])

                    X_train['uplift'] = y_train_pred1 - y_train_pred2
                    X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                    train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                    verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                    new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                    monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                    new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                    monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                    print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                    print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                    pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                                 {'learning_rate': learning_rate,'criterion':criterion,'n_estimators': n_estimators, \
                              'min_samples_leaf':min_samples_leaf, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.005
# n_estimators: 60
# criterion: friedman_mse
# min_samples_leaf: 1
# max_depth: 5
# train_qini_auc_score: 0.11900510125954662, verify_qini_auc_score: 0.035519906103423635
# monotonicity_train: 0.9878787878787878, monotonicity_verify: 0.2727272727272727
# [{'auc_score': 0.035519906103423635, 'monotonicity': 0.2727272727272727, 'params': {'learning_rate': 0.005, 'criterion': 'friedman_mse', 'n_estimators': 60, 'min_samples_leaf': 1, 'max_depth': 5}}]

# %%
# 模型保存
dump(model1, 'result/mens_visit/gbdt_model1.joblib')
dump(model2, 'result/mens_visit/gbdt_model2.joblib')
# Out:
# ['result/mens_visit/gbdt_model2.joblib']

# %%
'''
best_param:
learning_rate: 0.02
n_estimators: 50
criterion: friedman_mse
min_samples_leaf: 1
max_depth: 2
    
best_auuc_param:
n_estimators: 60
criterion: friedman_mse
min_samples_leaf: 1
max_depth: 2
'''
# Out:
# '\nbest_param:\nlearning_rate: 0.02\nn_estimators: 50\ncriterion: friedman_mse\nmin_samples_leaf: 1\nmax_depth: 2\n    \nbest_auuc_param:\nn_estimators: 60\ncriterion: friedman_mse\nmin_samples_leaf: 1\nmax_depth: 2\n'

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.11900510125954662
# 0.035519906103423635

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0831'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.02,0.03,0.05,0.1], 'n_estimators':[70,80,90,100], 
#                'subsample':[0.35,0.4,0.45], 'max_depth': [3,4,5]}

search_params = {'learning_rate': [0.03], 'n_estimators':[80], 
                'subsample':[0.4], 'max_depth': [4]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for subsample in search_params['subsample']:
            print('subsample: %s' % subsample)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model1 = XGBRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                y_train_pred1 = model1.predict(X_train[X_columns])
                y_verify_pred1 = model1.predict(X_verify[X_columns])
                
                model2 = XGBRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                y_train_pred2 = model2.predict(X_train[X_columns])
                y_verify_pred2= model2.predict(X_verify[X_columns])

                X_train['uplift'] = y_train_pred1 - y_train_pred2
                X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result,\
                             {'learning_rate': learning_rate,'n_estimators': n_estimators, \
                              'subsample':subsample, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.03
# n_estimators: 80
# subsample: 0.4
# max_depth: 4
# train_qini_auc_score: 0.2124927467603563, verify_qini_auc_score: 0.04870751051903935
# monotonicity_train: 0.9878787878787878, monotonicity_verify: 0.7575757575757575
# [{'auc_score': 0.04870751051903935, 'monotonicity': 0.7575757575757575, 'params': {'learning_rate': 0.03, 'n_estimators': 80, 'subsample': 0.4, 'max_depth': 4}}]

# %%
'''
best_params:
learning_rate: 0.01
n_estimators: 40
subsample: 0.4
max_depth: 2
'''
# Out:
# '\nbest_params:\nlearning_rate: 0.01\nn_estimators: 40\nsubsample: 0.4\nmax_depth: 2\n'

# %%
# 模型保存
dump(model1, 'result/mens_visit/xgb_model1.joblib')
dump(model2, 'result/mens_visit/xgb_model2.joblib')
# Out:
# ['result/mens_visit/xgb_model2.joblib']

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.2124927467603563
# 0.04870751051903935

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0831'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

#search_params = {'learning_rate': [0.02,0.03,0.04], 'n_estimators':[100,150,200,250], 
#                'subsample':[0.4,0.5,0.6,0.7], 'max_depth': [2,3,4]}

search_params = {'learning_rate': [0.03], 'n_estimators':[200], 
                'subsample':[0.4], 'max_depth': [3]}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for learning_rate in search_params['learning_rate']:
    print('learning_rate: %s' % learning_rate)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for subsample in search_params['subsample']:
            print('subsample: %s' % subsample)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model1 = CatBoostRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model1.fit(X_train_exp[X_columns],X_train_exp[y_columns])

                y_train_pred1 = model1.predict(X_train[X_columns])
                y_verify_pred1 = model1.predict(X_verify[X_columns])
                
                model2 = CatBoostRegressor(learning_rate=learning_rate, n_estimators=n_estimators,
                                                      subsample=subsample, max_depth=max_depth) 
                model2.fit(X_train_base[X_columns],X_train_base[y_columns])

                y_train_pred2 = model2.predict(X_train[X_columns])
                y_verify_pred2= model2.predict(X_verify[X_columns])

                X_train['uplift'] = y_train_pred1 - y_train_pred2
                X_verify['uplift'] = y_verify_pred1 - y_verify_pred2
                    
                train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                              {'learning_rate':learning_rate,'n_estimators': n_estimators, \
                              'subsample':subsample, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# learning_rate: 0.03
# n_estimators: 200
# subsample: 0.4
# max_depth: 3
# 0:	learn: 0.3838961	total: 950us	remaining: 189ms
# 1:	learn: 0.3837806	total: 1.89ms	remaining: 187ms
# 2:	learn: 0.3836284	total: 2.93ms	remaining: 192ms
# 3:	learn: 0.3834693	total: 4ms	remaining: 196ms
# 4:	learn: 0.3833210	total: 4.88ms	remaining: 190ms
# 5:	learn: 0.3831754	total: 5.71ms	remaining: 185ms
# 6:	learn: 0.3830904	total: 6.53ms	remaining: 180ms
# 7:	learn: 0.3829641	total: 7.43ms	remaining: 178ms
# 8:	learn: 0.3828362	total: 8.34ms	remaining: 177ms
# 9:	learn: 0.3827224	total: 9.15ms	remaining: 174ms
# 10:	learn: 0.3826057	total: 10.1ms	remaining: 173ms
# 11:	learn: 0.3825049	total: 10.8ms	remaining: 170ms
# 12:	learn: 0.3823986	total: 11.6ms	remaining: 167ms
# 13:	learn: 0.3823026	total: 12.5ms	remaining: 166ms
# 14:	learn: 0.3822206	total: 13.4ms	remaining: 165ms
# 15:	learn: 0.3821272	total: 14.1ms	remaining: 162ms
# 16:	learn: 0.3820544	total: 14.9ms	remaining: 160ms
# 17:	learn: 0.3819734	total: 15.6ms	remaining: 158ms
# 18:	learn: 0.3818903	total: 16.3ms	remaining: 156ms
# 19:	learn: 0.3818368	total: 17.2ms	remaining: 155ms
# 20:	learn: 0.3817688	total: 18ms	remaining: 153ms
# 21:	learn: 0.3817124	total: 18.7ms	remaining: 152ms
# 22:	learn: 0.3815883	total: 19.6ms	remaining: 151ms
# 23:	learn: 0.3815339	total: 20.5ms	remaining: 150ms
# 24:	learn: 0.3814472	total: 21.2ms	remaining: 148ms
# 25:	learn: 0.3813889	total: 22ms	remaining: 148ms
# 26:	learn: 0.3813476	total: 22.9ms	remaining: 147ms
# 27:	learn: 0.3812968	total: 23.7ms	remaining: 146ms
# 28:	learn: 0.3812289	total: 24.6ms	remaining: 145ms
# 29:	learn: 0.3811843	total: 25.4ms	remaining: 144ms
# 30:	learn: 0.3811313	total: 26.3ms	remaining: 143ms
# 31:	learn: 0.3810720	total: 27.1ms	remaining: 142ms
# 32:	learn: 0.3810249	total: 27.9ms	remaining: 141ms
# 33:	learn: 0.3809789	total: 28.8ms	remaining: 141ms
# 34:	learn: 0.3809364	total: 29.6ms	remaining: 140ms
# 35:	learn: 0.3808971	total: 30.6ms	remaining: 139ms
# 36:	learn: 0.3808572	total: 31.4ms	remaining: 138ms
# 37:	learn: 0.3808084	total: 32.3ms	remaining: 138ms
# 38:	learn: 0.3807734	total: 33.1ms	remaining: 137ms
# 39:	learn: 0.3807427	total: 34ms	remaining: 136ms
# 40:	learn: 0.3807165	total: 34.8ms	remaining: 135ms
# 41:	learn: 0.3806778	total: 35.6ms	remaining: 134ms
# 42:	learn: 0.3806435	total: 36.5ms	remaining: 133ms
# 43:	learn: 0.3806109	total: 37.3ms	remaining: 132ms
# 44:	learn: 0.3805715	total: 38.1ms	remaining: 131ms
# 45:	learn: 0.3805382	total: 38.9ms	remaining: 130ms
# 46:	learn: 0.3805056	total: 39.7ms	remaining: 129ms
# 47:	learn: 0.3804838	total: 40.4ms	remaining: 128ms
# 48:	learn: 0.3804577	total: 41.2ms	remaining: 127ms
# 49:	learn: 0.3803676	total: 42.1ms	remaining: 126ms
# 50:	learn: 0.3803447	total: 43ms	remaining: 126ms
# 51:	learn: 0.3803084	total: 43.9ms	remaining: 125ms
# 52:	learn: 0.3802666	total: 44.8ms	remaining: 124ms
# 53:	learn: 0.3802538	total: 45.5ms	remaining: 123ms
# 54:	learn: 0.3801537	total: 46.3ms	remaining: 122ms
# 55:	learn: 0.3801198	total: 47ms	remaining: 121ms
# 56:	learn: 0.3800888	total: 47.8ms	remaining: 120ms
# 57:	learn: 0.3800735	total: 48.7ms	remaining: 119ms
# 58:	learn: 0.3800605	total: 49.6ms	remaining: 118ms
# 59:	learn: 0.3799755	total: 50.3ms	remaining: 117ms
# 60:	learn: 0.3799670	total: 51ms	remaining: 116ms
# 61:	learn: 0.3798986	total: 51.8ms	remaining: 115ms
# 62:	learn: 0.3798718	total: 52.7ms	remaining: 115ms
# 63:	learn: 0.3798440	total: 53.5ms	remaining: 114ms
# 64:	learn: 0.3798174	total: 54.3ms	remaining: 113ms
# 65:	learn: 0.3798044	total: 55.2ms	remaining: 112ms
# 66:	learn: 0.3797893	total: 56.1ms	remaining: 111ms
# 67:	learn: 0.3797642	total: 57ms	remaining: 111ms
# 68:	learn: 0.3797465	total: 58.1ms	remaining: 110ms
# 69:	learn: 0.3797360	total: 59ms	remaining: 110ms
# 70:	learn: 0.3797236	total: 59.7ms	remaining: 109ms
# 71:	learn: 0.3796512	total: 60.6ms	remaining: 108ms
# 72:	learn: 0.3796365	total: 61.5ms	remaining: 107ms
# 73:	learn: 0.3796177	total: 62.5ms	remaining: 106ms
# 74:	learn: 0.3796000	total: 63.2ms	remaining: 105ms
# 75:	learn: 0.3795758	total: 64.1ms	remaining: 105ms
# 76:	learn: 0.3795522	total: 65ms	remaining: 104ms
# 77:	learn: 0.3795433	total: 66ms	remaining: 103ms
# 78:	learn: 0.3794700	total: 66.9ms	remaining: 102ms
# 79:	learn: 0.3794534	total: 67.9ms	remaining: 102ms
# 80:	learn: 0.3794319	total: 68.8ms	remaining: 101ms
# 81:	learn: 0.3794113	total: 69.8ms	remaining: 100ms
# 82:	learn: 0.3793899	total: 71ms	remaining: 100ms
# 83:	learn: 0.3793727	total: 71.8ms	remaining: 99.2ms
# 84:	learn: 0.3793535	total: 72.7ms	remaining: 98.3ms
# 85:	learn: 0.3793007	total: 73.6ms	remaining: 97.5ms
# 86:	learn: 0.3792950	total: 74.5ms	remaining: 96.8ms
# 87:	learn: 0.3792811	total: 75.4ms	remaining: 96ms
# 88:	learn: 0.3792565	total: 76.3ms	remaining: 95.1ms
# 89:	learn: 0.3792082	total: 77.2ms	remaining: 94.4ms
# 90:	learn: 0.3791969	total: 78.1ms	remaining: 93.6ms
# 91:	learn: 0.3791821	total: 79.1ms	remaining: 92.9ms
# 92:	learn: 0.3791672	total: 80ms	remaining: 92ms
# 93:	learn: 0.3791623	total: 80.8ms	remaining: 91.1ms
# 94:	learn: 0.3791451	total: 81.7ms	remaining: 90.3ms
# 95:	learn: 0.3791306	total: 82.8ms	remaining: 89.7ms
# 96:	learn: 0.3791263	total: 83.9ms	remaining: 89.1ms
# 97:	learn: 0.3791079	total: 84.9ms	remaining: 88.4ms
# 98:	learn: 0.3790981	total: 86.5ms	remaining: 88.3ms
# 99:	learn: 0.3790842	total: 88.2ms	remaining: 88.2ms
# 100:	learn: 0.3790789	total: 89.2ms	remaining: 87.5ms
# 101:	learn: 0.3790324	total: 90.2ms	remaining: 86.7ms
# 102:	learn: 0.3790186	total: 91.2ms	remaining: 85.8ms
# 103:	learn: 0.3790101	total: 92.2ms	remaining: 85.1ms
# 104:	learn: 0.3789589	total: 93.3ms	remaining: 84.4ms
# 105:	learn: 0.3789457	total: 94.1ms	remaining: 83.4ms
# 106:	learn: 0.3789348	total: 95ms	remaining: 82.5ms
# 107:	learn: 0.3789232	total: 95.9ms	remaining: 81.7ms
# 108:	learn: 0.3789151	total: 96.6ms	remaining: 80.7ms
# 109:	learn: 0.3788774	total: 97.4ms	remaining: 79.7ms
# 110:	learn: 0.3788671	total: 98.3ms	remaining: 78.8ms
# 111:	learn: 0.3788553	total: 99.2ms	remaining: 77.9ms
# 112:	learn: 0.3788492	total: 102ms	remaining: 78.3ms
# 113:	learn: 0.3788419	total: 103ms	remaining: 77.8ms
# 114:	learn: 0.3788253	total: 104ms	remaining: 77.2ms
# 115:	learn: 0.3788216	total: 106ms	remaining: 76.5ms
# 116:	learn: 0.3788089	total: 107ms	remaining: 75.6ms
# 117:	learn: 0.3788008	total: 108ms	remaining: 74.8ms
# 118:	learn: 0.3787934	total: 109ms	remaining: 74.1ms
# 119:	learn: 0.3787854	total: 110ms	remaining: 73.4ms
# 120:	learn: 0.3787764	total: 111ms	remaining: 72.7ms
# 121:	learn: 0.3787669	total: 113ms	remaining: 71.9ms
# 122:	learn: 0.3787634	total: 113ms	remaining: 71ms
# 123:	learn: 0.3787232	total: 114ms	remaining: 70ms
# 124:	learn: 0.3787147	total: 115ms	remaining: 69.1ms
# 125:	learn: 0.3787023	total: 116ms	remaining: 68.3ms
# 126:	learn: 0.3786964	total: 117ms	remaining: 67.4ms
# 127:	learn: 0.3786869	total: 119ms	remaining: 66.7ms
# 128:	learn: 0.3786843	total: 120ms	remaining: 66ms
# 129:	learn: 0.3786434	total: 122ms	remaining: 65.5ms
# 130:	learn: 0.3786373	total: 123ms	remaining: 64.7ms
# 131:	learn: 0.3786031	total: 124ms	remaining: 63.8ms
# 132:	learn: 0.3785950	total: 125ms	remaining: 62.9ms
# 133:	learn: 0.3785808	total: 126ms	remaining: 61.9ms
# 134:	learn: 0.3785694	total: 127ms	remaining: 61ms
# 135:	learn: 0.3785607	total: 128ms	remaining: 60ms
# 136:	learn: 0.3785580	total: 128ms	remaining: 59ms
# 137:	learn: 0.3785455	total: 129ms	remaining: 58ms
# 138:	learn: 0.3785392	total: 130ms	remaining: 57.1ms
# 139:	learn: 0.3785306	total: 131ms	remaining: 56.1ms
# 140:	learn: 0.3785220	total: 132ms	remaining: 55.1ms
# 141:	learn: 0.3785138	total: 133ms	remaining: 54.1ms
# 142:	learn: 0.3785113	total: 133ms	remaining: 53.1ms
# 143:	learn: 0.3785034	total: 134ms	remaining: 52.1ms
# 144:	learn: 0.3784985	total: 135ms	remaining: 51.1ms
# 145:	learn: 0.3784963	total: 135ms	remaining: 50.1ms
# 146:	learn: 0.3784865	total: 136ms	remaining: 49.1ms
# 147:	learn: 0.3784838	total: 137ms	remaining: 48.2ms
# 148:	learn: 0.3784719	total: 138ms	remaining: 47.2ms
# 149:	learn: 0.3784632	total: 139ms	remaining: 46.2ms
# 150:	learn: 0.3784570	total: 139ms	remaining: 45.3ms
# 151:	learn: 0.3784455	total: 140ms	remaining: 44.3ms
# 152:	learn: 0.3784407	total: 141ms	remaining: 43.3ms
# 153:	learn: 0.3784086	total: 142ms	remaining: 42.4ms
# 154:	learn: 0.3783995	total: 143ms	remaining: 41.5ms
# 155:	learn: 0.3783840	total: 144ms	remaining: 40.6ms
# 156:	learn: 0.3783759	total: 145ms	remaining: 39.7ms
# 157:	learn: 0.3783484	total: 146ms	remaining: 38.7ms
# 158:	learn: 0.3783317	total: 147ms	remaining: 37.8ms
# 159:	learn: 0.3783227	total: 148ms	remaining: 36.9ms
# 160:	learn: 0.3783156	total: 148ms	remaining: 35.9ms
# 161:	learn: 0.3783112	total: 149ms	remaining: 35ms
# 162:	learn: 0.3783050	total: 150ms	remaining: 34ms
# 163:	learn: 0.3782997	total: 151ms	remaining: 33.1ms
# 164:	learn: 0.3782945	total: 151ms	remaining: 32.1ms
# 165:	learn: 0.3782863	total: 152ms	remaining: 31.2ms
# 166:	learn: 0.3782782	total: 153ms	remaining: 30.2ms
# 167:	learn: 0.3782755	total: 154ms	remaining: 29.3ms
# 168:	learn: 0.3782508	total: 155ms	remaining: 28.4ms
# 169:	learn: 0.3782413	total: 155ms	remaining: 27.4ms
# 170:	learn: 0.3782309	total: 156ms	remaining: 26.5ms
# 171:	learn: 0.3782232	total: 157ms	remaining: 25.6ms
# 172:	learn: 0.3782183	total: 159ms	remaining: 24.8ms
# 173:	learn: 0.3782181	total: 160ms	remaining: 23.9ms
# 174:	learn: 0.3782099	total: 162ms	remaining: 23.1ms
# 175:	learn: 0.3782055	total: 163ms	remaining: 22.3ms
# 176:	learn: 0.3781982	total: 164ms	remaining: 21.4ms
# 177:	learn: 0.3781773	total: 165ms	remaining: 20.4ms
# 178:	learn: 0.3781562	total: 166ms	remaining: 19.5ms
# 179:	learn: 0.3781505	total: 167ms	remaining: 18.6ms
# 180:	learn: 0.3781437	total: 168ms	remaining: 17.6ms
# 181:	learn: 0.3781390	total: 169ms	remaining: 16.7ms
# 182:	learn: 0.3781382	total: 170ms	remaining: 15.8ms
# 183:	learn: 0.3781319	total: 171ms	remaining: 14.9ms
# 184:	learn: 0.3781172	total: 172ms	remaining: 13.9ms
# 185:	learn: 0.3781079	total: 173ms	remaining: 13ms
# 186:	learn: 0.3781021	total: 174ms	remaining: 12.1ms
# 187:	learn: 0.3780957	total: 175ms	remaining: 11.2ms
# 188:	learn: 0.3780891	total: 176ms	remaining: 10.2ms
# 189:	learn: 0.3780832	total: 177ms	remaining: 9.32ms
# 190:	learn: 0.3780760	total: 178ms	remaining: 8.38ms
# 191:	learn: 0.3780542	total: 179ms	remaining: 7.45ms
# 192:	learn: 0.3780494	total: 180ms	remaining: 6.52ms
# 193:	learn: 0.3780469	total: 181ms	remaining: 5.58ms
# 194:	learn: 0.3780385	total: 181ms	remaining: 4.65ms
# 195:	learn: 0.3780296	total: 182ms	remaining: 3.72ms
# 196:	learn: 0.3780247	total: 183ms	remaining: 2.79ms
# 197:	learn: 0.3780156	total: 184ms	remaining: 1.86ms
# 198:	learn: 0.3780090	total: 185ms	remaining: 928us
# 199:	learn: 0.3779905	total: 186ms	remaining: 0us
# 0:	learn: 0.3081067	total: 779us	remaining: 155ms
# 1:	learn: 0.3079468	total: 1.59ms	remaining: 158ms
# 2:	learn: 0.3078021	total: 2.59ms	remaining: 170ms
# 3:	learn: 0.3076575	total: 3.68ms	remaining: 180ms
# 4:	learn: 0.3075413	total: 5.33ms	remaining: 208ms
# 5:	learn: 0.3074195	total: 6.6ms	remaining: 213ms
# 6:	learn: 0.3073061	total: 8.17ms	remaining: 225ms
# 7:	learn: 0.3071629	total: 9.19ms	remaining: 221ms
# 8:	learn: 0.3070282	total: 10.2ms	remaining: 216ms
# 9:	learn: 0.3069258	total: 11.1ms	remaining: 210ms
# 10:	learn: 0.3068192	total: 12.1ms	remaining: 207ms
# 11:	learn: 0.3067180	total: 13ms	remaining: 203ms
# 12:	learn: 0.3066079	total: 13.9ms	remaining: 199ms
# 13:	learn: 0.3065143	total: 14.6ms	remaining: 194ms
# 14:	learn: 0.3064220	total: 15.4ms	remaining: 190ms
# 15:	learn: 0.3063396	total: 16.3ms	remaining: 187ms
# 16:	learn: 0.3062598	total: 17.4ms	remaining: 188ms
# 17:	learn: 0.3061703	total: 18.7ms	remaining: 189ms
# 18:	learn: 0.3061174	total: 19.8ms	remaining: 188ms
# 19:	learn: 0.3060413	total: 20.8ms	remaining: 187ms
# 20:	learn: 0.3059864	total: 21.9ms	remaining: 186ms
# 21:	learn: 0.3058989	total: 22.8ms	remaining: 185ms
# 22:	learn: 0.3058419	total: 23.8ms	remaining: 183ms
# 23:	learn: 0.3057742	total: 24.6ms	remaining: 181ms
# 24:	learn: 0.3057095	total: 25.3ms	remaining: 177ms
# 25:	learn: 0.3056508	total: 26ms	remaining: 174ms
# 26:	learn: 0.3056057	total: 26.9ms	remaining: 172ms
# 27:	learn: 0.3055338	total: 28ms	remaining: 172ms
# 28:	learn: 0.3054690	total: 28.9ms	remaining: 170ms
# 29:	learn: 0.3054154	total: 29.9ms	remaining: 169ms
# 30:	learn: 0.3053610	total: 30.7ms	remaining: 167ms
# 31:	learn: 0.3053052	total: 31.7ms	remaining: 166ms
# 32:	learn: 0.3052666	total: 32.6ms	remaining: 165ms
# 33:	learn: 0.3052109	total: 33.3ms	remaining: 163ms
# 34:	learn: 0.3051499	total: 34.2ms	remaining: 161ms
# 35:	learn: 0.3051275	total: 35.8ms	remaining: 163ms
# 36:	learn: 0.3050774	total: 37ms	remaining: 163ms
# 37:	learn: 0.3050312	total: 37.8ms	remaining: 161ms
# 38:	learn: 0.3049970	total: 38.9ms	remaining: 160ms
# 39:	learn: 0.3049605	total: 39.9ms	remaining: 159ms
# 40:	learn: 0.3049209	total: 40.9ms	remaining: 159ms
# 41:	learn: 0.3048892	total: 42ms	remaining: 158ms
# 42:	learn: 0.3048671	total: 43.1ms	remaining: 157ms
# 43:	learn: 0.3048170	total: 44.1ms	remaining: 156ms
# 44:	learn: 0.3047742	total: 45.1ms	remaining: 155ms
# 45:	learn: 0.3047318	total: 45.9ms	remaining: 154ms
# 46:	learn: 0.3047010	total: 46.8ms	remaining: 152ms
# 47:	learn: 0.3046811	total: 47.9ms	remaining: 152ms
# 48:	learn: 0.3046529	total: 48.8ms	remaining: 151ms
# 49:	learn: 0.3046175	total: 49.7ms	remaining: 149ms
# 50:	learn: 0.3045845	total: 50.5ms	remaining: 148ms
# 51:	learn: 0.3045518	total: 51.4ms	remaining: 146ms
# 52:	learn: 0.3045178	total: 52.3ms	remaining: 145ms
# 53:	learn: 0.3045074	total: 53.1ms	remaining: 144ms
# 54:	learn: 0.3044687	total: 54ms	remaining: 142ms
# 55:	learn: 0.3044485	total: 54.8ms	remaining: 141ms
# 56:	learn: 0.3044190	total: 55.6ms	remaining: 139ms
# 57:	learn: 0.3044029	total: 56.5ms	remaining: 138ms
# 58:	learn: 0.3043871	total: 57.3ms	remaining: 137ms
# 59:	learn: 0.3043556	total: 58.2ms	remaining: 136ms
# 60:	learn: 0.3043290	total: 58.8ms	remaining: 134ms
# 61:	learn: 0.3043069	total: 59.8ms	remaining: 133ms
# 62:	learn: 0.3042789	total: 60.6ms	remaining: 132ms
# 63:	learn: 0.3042557	total: 61.6ms	remaining: 131ms
# 64:	learn: 0.3042285	total: 62.4ms	remaining: 130ms
# 65:	learn: 0.3042181	total: 63.1ms	remaining: 128ms
# 66:	learn: 0.3041939	total: 63.8ms	remaining: 127ms
# 67:	learn: 0.3041628	total: 64.7ms	remaining: 126ms
# 68:	learn: 0.3041350	total: 65.4ms	remaining: 124ms
# 69:	learn: 0.3041214	total: 66.2ms	remaining: 123ms
# 70:	learn: 0.3040962	total: 67.1ms	remaining: 122ms
# 71:	learn: 0.3040806	total: 67.8ms	remaining: 120ms
# 72:	learn: 0.3040629	total: 68.6ms	remaining: 119ms
# 73:	learn: 0.3040404	total: 69.5ms	remaining: 118ms
# 74:	learn: 0.3040234	total: 70.2ms	remaining: 117ms
# 75:	learn: 0.3040072	total: 71ms	remaining: 116ms
# 76:	learn: 0.3039980	total: 72ms	remaining: 115ms
# 77:	learn: 0.3039746	total: 72.8ms	remaining: 114ms
# 78:	learn: 0.3039515	total: 73.6ms	remaining: 113ms
# 79:	learn: 0.3039303	total: 74.4ms	remaining: 112ms
# 80:	learn: 0.3039115	total: 75.2ms	remaining: 111ms
# 81:	learn: 0.3038969	total: 76.1ms	remaining: 109ms
# 82:	learn: 0.3038892	total: 76.8ms	remaining: 108ms
# 83:	learn: 0.3038685	total: 77.6ms	remaining: 107ms
# 84:	learn: 0.3038570	total: 78.3ms	remaining: 106ms
# 85:	learn: 0.3038442	total: 79.1ms	remaining: 105ms
# 86:	learn: 0.3038278	total: 79.8ms	remaining: 104ms
# 87:	learn: 0.3038130	total: 80.6ms	remaining: 103ms
# 88:	learn: 0.3037966	total: 81.3ms	remaining: 101ms
# 89:	learn: 0.3037834	total: 82ms	remaining: 100ms
# 90:	learn: 0.3037729	total: 82.9ms	remaining: 99.2ms
# 91:	learn: 0.3037633	total: 83.6ms	remaining: 98.1ms
# 92:	learn: 0.3037525	total: 84.4ms	remaining: 97.1ms
# 93:	learn: 0.3037395	total: 85.4ms	remaining: 96.3ms
# 94:	learn: 0.3037295	total: 86.5ms	remaining: 95.6ms
# 95:	learn: 0.3037174	total: 88.8ms	remaining: 96.2ms
# 96:	learn: 0.3037089	total: 90.3ms	remaining: 95.9ms
# 97:	learn: 0.3036894	total: 93.6ms	remaining: 97.4ms
# 98:	learn: 0.3036753	total: 94.8ms	remaining: 96.8ms
# 99:	learn: 0.3036598	total: 95.8ms	remaining: 95.8ms
# 100:	learn: 0.3036324	total: 98ms	remaining: 96.1ms
# 101:	learn: 0.3036243	total: 99ms	remaining: 95.1ms
# 102:	learn: 0.3036198	total: 100ms	remaining: 94.3ms
# 103:	learn: 0.3036108	total: 101ms	remaining: 93.3ms
# 104:	learn: 0.3036006	total: 102ms	remaining: 92.4ms
# 105:	learn: 0.3035839	total: 103ms	remaining: 91.3ms
# 106:	learn: 0.3035742	total: 104ms	remaining: 90.6ms
# 107:	learn: 0.3035583	total: 105ms	remaining: 89.6ms
# 108:	learn: 0.3035457	total: 106ms	remaining: 88.7ms
# 109:	learn: 0.3035337	total: 107ms	remaining: 87.5ms
# 110:	learn: 0.3035215	total: 108ms	remaining: 86.6ms
# 111:	learn: 0.3035067	total: 109ms	remaining: 85.7ms
# 112:	learn: 0.3035005	total: 110ms	remaining: 84.9ms
# 113:	learn: 0.3034915	total: 111ms	remaining: 83.8ms
# 114:	learn: 0.3034680	total: 112ms	remaining: 82.8ms
# 115:	learn: 0.3034621	total: 113ms	remaining: 81.8ms
# 116:	learn: 0.3034584	total: 114ms	remaining: 80.9ms
# 117:	learn: 0.3034433	total: 115ms	remaining: 79.9ms
# 118:	learn: 0.3034249	total: 116ms	remaining: 78.9ms
# 119:	learn: 0.3034162	total: 117ms	remaining: 77.7ms
# 120:	learn: 0.3034062	total: 118ms	remaining: 76.7ms
# 121:	learn: 0.3034012	total: 121ms	remaining: 77.1ms
# 122:	learn: 0.3033874	total: 122ms	remaining: 76.2ms
# 123:	learn: 0.3033805	total: 122ms	remaining: 75.1ms
# 124:	learn: 0.3033687	total: 123ms	remaining: 74ms
# 125:	learn: 0.3033639	total: 124ms	remaining: 72.9ms
# 126:	learn: 0.3033552	total: 125ms	remaining: 71.8ms
# 127:	learn: 0.3033447	total: 126ms	remaining: 70.6ms
# 128:	learn: 0.3033212	total: 126ms	remaining: 69.5ms
# 129:	learn: 0.3033123	total: 127ms	remaining: 68.5ms
# 130:	learn: 0.3033044	total: 128ms	remaining: 67.3ms
# 131:	learn: 0.3032979	total: 129ms	remaining: 66.3ms
# 132:	learn: 0.3032925	total: 130ms	remaining: 65.2ms
# 133:	learn: 0.3032869	total: 130ms	remaining: 64.2ms
# 134:	learn: 0.3032583	total: 131ms	remaining: 63.1ms
# 135:	learn: 0.3032518	total: 132ms	remaining: 62.1ms
# 136:	learn: 0.3032438	total: 133ms	remaining: 61.1ms
# 137:	learn: 0.3032352	total: 134ms	remaining: 60ms
# 138:	learn: 0.3032276	total: 134ms	remaining: 58.9ms
# 139:	learn: 0.3032224	total: 135ms	remaining: 57.9ms
# 140:	learn: 0.3032190	total: 136ms	remaining: 56.8ms
# 141:	learn: 0.3032153	total: 137ms	remaining: 55.8ms
# 142:	learn: 0.3032083	total: 137ms	remaining: 54.7ms
# 143:	learn: 0.3031907	total: 138ms	remaining: 53.7ms
# 144:	learn: 0.3031835	total: 139ms	remaining: 52.6ms
# 145:	learn: 0.3031810	total: 140ms	remaining: 51.6ms
# 146:	learn: 0.3031735	total: 141ms	remaining: 50.8ms
# 147:	learn: 0.3031682	total: 142ms	remaining: 49.7ms
# 148:	learn: 0.3031602	total: 142ms	remaining: 48.7ms
# 149:	learn: 0.3031548	total: 143ms	remaining: 47.7ms
# 150:	learn: 0.3031475	total: 144ms	remaining: 46.7ms
# 151:	learn: 0.3031432	total: 145ms	remaining: 45.7ms
# 152:	learn: 0.3031377	total: 145ms	remaining: 44.7ms
# 153:	learn: 0.3031292	total: 146ms	remaining: 43.7ms
# 154:	learn: 0.3031235	total: 147ms	remaining: 42.7ms
# 155:	learn: 0.3031166	total: 148ms	remaining: 41.8ms
# 156:	learn: 0.3031133	total: 149ms	remaining: 40.8ms
# 157:	learn: 0.3031109	total: 150ms	remaining: 39.9ms
# 158:	learn: 0.3030912	total: 151ms	remaining: 38.8ms
# 159:	learn: 0.3030848	total: 151ms	remaining: 37.9ms
# 160:	learn: 0.3030806	total: 152ms	remaining: 36.9ms
# 161:	learn: 0.3030753	total: 153ms	remaining: 35.9ms
# 162:	learn: 0.3030690	total: 154ms	remaining: 34.9ms
# 163:	learn: 0.3030626	total: 155ms	remaining: 34ms
# 164:	learn: 0.3030487	total: 156ms	remaining: 33ms
# 165:	learn: 0.3030335	total: 156ms	remaining: 32ms
# 166:	learn: 0.3030274	total: 157ms	remaining: 31.1ms
# 167:	learn: 0.3030178	total: 158ms	remaining: 30.1ms
# 168:	learn: 0.3030086	total: 159ms	remaining: 29.1ms
# 169:	learn: 0.3030036	total: 160ms	remaining: 28.2ms
# 170:	learn: 0.3029937	total: 161ms	remaining: 27.2ms
# 171:	learn: 0.3029892	total: 161ms	remaining: 26.3ms
# 172:	learn: 0.3029863	total: 162ms	remaining: 25.3ms
# 173:	learn: 0.3029756	total: 163ms	remaining: 24.4ms
# 174:	learn: 0.3029704	total: 164ms	remaining: 23.4ms
# 175:	learn: 0.3029662	total: 165ms	remaining: 22.5ms
# 176:	learn: 0.3029607	total: 166ms	remaining: 21.5ms
# 177:	learn: 0.3029556	total: 166ms	remaining: 20.6ms
# 178:	learn: 0.3029420	total: 167ms	remaining: 19.6ms
# 179:	learn: 0.3029305	total: 168ms	remaining: 18.7ms
# 180:	learn: 0.3029272	total: 169ms	remaining: 17.7ms
# 181:	learn: 0.3029147	total: 170ms	remaining: 16.8ms
# 182:	learn: 0.3029109	total: 171ms	remaining: 15.9ms
# 183:	learn: 0.3029077	total: 171ms	remaining: 14.9ms
# 184:	learn: 0.3029039	total: 172ms	remaining: 14ms
# 185:	learn: 0.3028973	total: 173ms	remaining: 13ms
# 186:	learn: 0.3028951	total: 174ms	remaining: 12.1ms
# 187:	learn: 0.3028903	total: 175ms	remaining: 11.2ms
# 188:	learn: 0.3028835	total: 176ms	remaining: 10.2ms
# 189:	learn: 0.3028744	total: 177ms	remaining: 9.29ms
# 190:	learn: 0.3028702	total: 177ms	remaining: 8.36ms
# 191:	learn: 0.3028649	total: 178ms	remaining: 7.43ms
# 192:	learn: 0.3028599	total: 179ms	remaining: 6.5ms
# 193:	learn: 0.3028508	total: 180ms	remaining: 5.57ms
# 194:	learn: 0.3028498	total: 181ms	remaining: 4.63ms
# 195:	learn: 0.3028396	total: 181ms	remaining: 3.7ms
# 196:	learn: 0.3028374	total: 182ms	remaining: 2.78ms
# 197:	learn: 0.3028327	total: 183ms	remaining: 1.85ms
# 198:	learn: 0.3028292	total: 184ms	remaining: 923us
# 199:	learn: 0.3028194	total: 185ms	remaining: 0us
# train_qini_auc_score: 0.09407976212320808, verify_qini_auc_score: 0.02759573013134079
# monotonicity_train: 0.9636363636363635, monotonicity_verify: 0.406060606060606
# [{'auc_score': 0.02759573013134079, 'monotonicity': 0.406060606060606, 'params': {'learning_rate': 0.03, 'n_estimators': 200, 'subsample': 0.4, 'max_depth': 3}}]

# %%
# 模型保存
dump(model1, 'result/mens_visit/cat_boost_model1.joblib')
dump(model2, 'result/mens_visit/cat_boost_model2.joblib')
# Out:
# ['result/mens_visit/cat_boost_model2.joblib']

# %%
# best_params
#{'learning_rate': 0.02, 'n_estimators': 50, 'subsample': 0.4, 'max_depth': 2}

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.09407976212320808
# 0.02759573013134079

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0831'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %% [markdown]
# #### Part3 因果森林

# %%
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor,CatBoostClassifier

'''
search_params = {
    'n_estimators': [20,40,60,80,100,200],
    'min_samples_leaf': [1],
    'max_depth': [2,3,5],
    'max_samples': [0.3,0.4,0.5]
}
'''

search_params = {
    'n_estimators': [40],
    'min_samples_leaf': [1],
    'max_depth': [3],
    'max_samples': [0.5]
}

best_result=[{'auc_score':0, 'monotonicity':0}]
best_params={}
for max_samples in search_params['max_samples']:
    print('max_samples: %s' % max_samples)
    for n_estimators in search_params['n_estimators']:
        print('n_estimators: %s' % n_estimators)
        for min_samples_leaf in search_params['min_samples_leaf']:
            print('min_samples_leaf: %s' % min_samples_leaf)
            for max_depth in search_params['max_depth']:
                print('max_depth: %s' % max_depth)

                model = CausalForestDML(criterion='het', 
                                max_depth=max_depth,
                                n_estimators=n_estimators,  
                                min_samples_leaf=min_samples_leaf, 
                                max_samples=max_samples,
                                discrete_treatment=True,
                                honest=True,
                                inference=True,
                                cv=5)
                model.fit(X_train[y_columns], X_train[[treatment]], X=X_train[X_columns], W=None, cache_values=True)
                X_train['uplift'] = model.effect(X_train[X_columns])
                X_verify['uplift'] = model.effect(X_verify[X_columns])
                    
                train_qini_auc_score = qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment])
                verify_qini_auc_score = qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment])
                    
                new_df_train = plot_uplift(X_train, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_train = spearmanr(new_df_train[new_df_train['type']=='actual'].index,new_df_train[new_df_train['type']=='actual']['uplift_score'])[0]
                    
                new_df_verify = plot_uplift(X_verify, treatment=treatment, metric=y_columns, bins=10, is_plot=False)
                monotonicity_verify = spearmanr(new_df_verify[new_df_verify['type']=='actual'].index,new_df_verify[new_df_verify['type']=='actual']['uplift_score'])[0]
                    
                print('train_qini_auc_score: %s, verify_qini_auc_score: %s' % (train_qini_auc_score, verify_qini_auc_score))
                print('monotonicity_train: %s, monotonicity_verify: %s' % (monotonicity_train, monotonicity_verify))
                    
                pareto_result(verify_qini_auc_score, monotonicity_verify, best_result, \
                             {'max_samples':max_samples,'n_estimators': n_estimators, \
                              'min_samples_leaf':min_samples_leaf, 'max_depth':max_depth})
                        
print(best_result)
# Out:
# max_samples: 0.5
# n_estimators: 40
# min_samples_leaf: 1
# max_depth: 3
# train_qini_auc_score: 0.037988923937482134, verify_qini_auc_score: 0.027927278614631262
# monotonicity_train: 0.9030303030303028, monotonicity_verify: 0.7212121212121211
# [{'auc_score': 0.027927278614631262, 'monotonicity': 0.7212121212121211, 'params': {'max_samples': 0.5, 'n_estimators': 40, 'min_samples_leaf': 1, 'max_depth': 3}}]

# %%
# 模型保存
dump(model, 'result/mens_visit/causal_forest_model.joblib')
# Out:
# ['result/mens_visit/causal_forest_model.joblib']

# %%
#fig, ax = plt.subplots(1, 1)
#ax.set_title('Qini curves')
plot_qini_curve(X_train[y_columns], X_train['uplift'], X_train[treatment], perfect=False, name='train')
plot_qini_curve(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], perfect=False, name='verify')
print(qini_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
print(qini_auc_score(X_verify[y_columns], X_verify['uplift'], X_verify[treatment]))
#print(uplift_auc_score(X_train[y_columns], X_train['uplift'], X_train[treatment]))
#print(auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment))
# Out:
# 0.037988923937482134
# 0.027927278614631262

# %%
plot_uplift_by_percentile(X_verify[y_columns], X_verify['uplift'], X_verify[treatment], \
                          strategy='by_group', kind='bar')
# Out:
# array([<AxesSubplot:title={'center':'Uplift by percentile\nweighted average uplift = 0.0831'}>,
#        <AxesSubplot:title={'center':'Response rate by percentile'}, xlabel='Percentile'>],
#       dtype=object)

# %%
# 连续变量
#plot_gain(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)
#auuc_score(X_train[[y_columns, treatment, 'uplift']], outcome_col=y_columns, treatment_col=treatment)

# %%
## 多模型比较
gbdt_model1 = load('result/mens_visit/gbdt_model1.joblib')
gbdt_model2 = load('result/mens_visit/gbdt_model2.joblib')

X_test['gbdt_uplift'] = gbdt_model1.predict(X_test[X_columns]) - gbdt_model2.predict(X_test[X_columns])

xgb_model1 = load('result/mens_visit/xgb_model1.joblib')
xgb_model2 = load('result/mens_visit/xgb_model2.joblib')

X_test['xgb_uplift'] = xgb_model1.predict(X_test[X_columns]) - xgb_model2.predict(X_test[X_columns])

cat_boost_model1 = load('result/mens_visit/cat_boost_model1.joblib')
cat_boost_model2 = load('result/mens_visit/cat_boost_model2.joblib')

X_test['cat_boost_uplift'] = cat_boost_model1.predict(X_test[X_columns]) - cat_boost_model2.predict(X_test[X_columns])

causal_forest_model = load('result/mens_visit/causal_forest_model.joblib')
X_test['causal_forest_uplift'] = causal_forest_model.effect(X_test[X_columns])
#X_test['causal_forest_uplift'] = causal_forest_model.const_marginal_effect(X_test[X_columns])

# %%
fig, ax = plt.subplots(1, 1)
ax.set_title('Qini curves')
plot_qini_curve(X_test[y_columns], X_test['gbdt_uplift'], X_test[treatment], perfect=False, name='GBDT', ax=ax)
plot_qini_curve(X_test[y_columns], X_test['xgb_uplift'], X_test[treatment], perfect=False, name='XGB', ax=ax)
plot_qini_curve(X_test[y_columns], X_test['cat_boost_uplift'], X_test[treatment], perfect=False, name='CAT_BOOST', ax=ax)
plot_qini_curve(X_test[y_columns], X_test['causal_forest_uplift'], X_test[treatment], perfect=False, name='CAUSAL_FOREST', ax=ax)
print('GBDT QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['gbdt_uplift'], X_test[treatment]))
print('XGB QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['xgb_uplift'], X_test[treatment]))
print('CAT BOOST QINI SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['cat_boost_uplift'], X_test[treatment]))
print('CAUSAL FOREST SCORE: %s' % qini_auc_score(X_test[y_columns], X_test['causal_forest_uplift'], X_test[treatment]))
# Out:
# GBDT QINI SCORE: 0.008904561106465852
# XGB QINI SCORE: 0.014750712524974882
# CAT BOOST QINI SCORE: 0.015015393989953522
# CAUSAL FOREST SCORE: 0.011733792906535126

# %% [markdown]
# ## 第四部分：收益回归
# uplift排名前15%的人群收益和uplift排名后15%的人群收益（也用来衡量偏序关系寻优的效果）

# %%
bottom = np.percentile(X_test['cat_boost_uplift'], 15.6)
up = np.percentile(X_test['cat_boost_uplift'], 100-15.6)

# %%
up
# Out:
# 0.09178172461377206

# %%
good = X_test[X_test['cat_boost_uplift']>=up]
bad = X_test[X_test['cat_boost_uplift']<=bottom]
print(len(good))
print(len(bad))
print(len(X_test))
# Out:
# 1995
# 1995
# 12785

# %%
good_exp = good[good[treatment]==1]
good_base = good[good[treatment]==0]
print('good人群对visit的处理效应：%s' % (good_exp['visit'].mean() - good_base['visit'].mean()))
print('good人群对conversion的处理效应：%s' % (good_exp['conversion'].mean() - good_base['conversion'].mean()))
print('good人群对spend的处理效应：%s' % (good_exp['spend'].mean() - good_base['spend'].mean()))
# Out:
# good人群对visit的处理效应：0.0910836936399105
# good人群对conversion的处理效应：0.008173984357568852
# good人群对spend的处理效应：1.4516177011535842

# %%
bad_exp = bad[bad[treatment]==1]
bad_base = bad[bad[treatment]==0]
print('bad人群对visit的处理效应：%s' % (bad_exp['visit'].mean() - bad_base['visit'].mean()))
print('bad人群对conversion的处理效应：%s' % (bad_exp['conversion'].mean() - bad_base['conversion'].mean()))
print('bad人群对spend的处理效应：%s' % (bad_exp['spend'].mean() - bad_base['spend'].mean()))
# Out:
# bad人群对visit的处理效应：0.08283500760055658
# bad人群对conversion的处理效应：0.007261748691015257
# bad人群对spend的处理效应：0.5494889932680785

# %% [markdown]
# ## 第五部分：提炼人群共性

# %%
label = 'causal_forest_uplift'

search_params = {'criterion': ['mse'],
                'max_depth': [2,3],
                'max_features': ['auto','sqrt','log2'],
                'min_impurity_decrease': [0,0.00001,0.0001,0.001,0.01]}

tree_train, tree_test = train_test_split(X_test, test_size=0.3, random_state=0)

best_score = 0
best_params = {}
best_model = None

for criterion in search_params['criterion']:
    print('criterion: %s' % criterion)
    for max_depth in search_params['max_depth']:
        print('max_depth: %s' % max_depth)
        for max_features in search_params['max_features']:
            print('max_features: %s' % max_features)
            for min_impurity_decrease in search_params['min_impurity_decrease']:
                print('min_impurity_decrease: %s' % min_impurity_decrease)
                tree_model = DecisionTreeRegressor(criterion=criterion,
                                                 splitter='best',
                                                 max_depth=max_depth,
                                                 min_samples_split=2,
                                                 min_samples_leaf=1,
                                                 min_weight_fraction_leaf=0,
                                                 max_features=max_features,
                                                 random_state=None,
                                                 max_leaf_nodes=None,
                                                 min_impurity_decrease=min_impurity_decrease)
                tree_model.fit(tree_train[X_columns], tree_train[label])
                
                tree_train_score = tree_model.score(tree_train[X_columns], tree_train[label])
                tree_test_score = tree_model.score(tree_test[X_columns], tree_test[label])
                
                print('tree_train_score: %s, tree_test_score: %s' % (tree_train_score, tree_test_score))
                
                if tree_test_score > best_score:
                    best_score = tree_test_score
                    best_params = {'criterion': criterion, 'max_depth': max_depth, 
                                  'max_features': max_features, 'min_impurity_decrease': min_impurity_decrease}
                    best_model = tree_model
    
print(best_score)
print(best_params)
# Out:
# criterion: mse
# max_depth: 2
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 0.6495600848374565, tree_test_score: 0.6545967391266607
# min_impurity_decrease: 1e-05
# tree_train_score: 0.4594045320021356, tree_test_score: 0.4528521127458983
# min_impurity_decrease: 0.0001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.01
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# max_features: sqrt
# min_impurity_decrease: 0
# tree_train_score: 0.5046593265018349, tree_test_score: 0.491449549267187
# min_impurity_decrease: 1e-05
# tree_train_score: 0.4594045320021355, tree_test_score: 0.4528521127458982
# min_impurity_decrease: 0.0001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.01
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# max_features: log2
# min_impurity_decrease: 0
# tree_train_score: 0.6205395951163232, tree_test_score: 0.6312182050964852
# min_impurity_decrease: 1e-05
# tree_train_score: 0.4594045320021356, tree_test_score: 0.4528521127458983
# min_impurity_decrease: 0.0001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.01
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# max_depth: 3
# max_features: auto
# min_impurity_decrease: 0
# tree_train_score: 0.7169975304165633, tree_test_score: 0.7251973832458936
# min_impurity_decrease: 1e-05
# tree_train_score: 0.4594045320021355, tree_test_score: 0.4528521127458983
# min_impurity_decrease: 0.0001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.01
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# max_features: sqrt
# min_impurity_decrease: 0
# tree_train_score: 0.5890221580855792, tree_test_score: 0.5895750538581661
# min_impurity_decrease: 1e-05
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.0001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.01
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# max_features: log2
# min_impurity_decrease: 0
# tree_train_score: 0.6056018251023408, tree_test_score: 0.6043485043848816
# min_impurity_decrease: 1e-05
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.0001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.001
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# min_impurity_decrease: 0.01
# tree_train_score: 1.1102230246251565e-16, tree_test_score: -0.00014070914560915249
# 0.7251973832458936
# {'criterion': 'mse', 'max_depth': 3, 'max_features': 'auto', 'min_impurity_decrease': 0}

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(best_model, 
                   feature_names=X_columns,  
                   filled=True)
